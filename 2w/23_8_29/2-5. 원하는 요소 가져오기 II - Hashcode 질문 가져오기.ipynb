# %% [markdown]
# ## 2-4. BeautifulSoup을 이용해 원하는 요소 가져오기 II - Hashcode 질문 가져오기
#
# - BeautifulSoup을 이용해서 Hashcode 질문 내용을 스크래핑해봅시다.

# %% [markdown]
# ### 스크래핑하고자 하는 사이트 확인하기
#
# 직접 접속해서 해당 사이트를 확인해봅시다 : https://hashcode.co.kr/
#
# 아래 두 가지 원칙을 지킵니다.
# 1. 과도한 요청을 보내지 않습니다.
# 2. 받아온 정보 활용에 유의합니다.

# %%
# 다음 User-Agent를 추가해봅시다.

user_agent = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36"}

# %%
# 필요한 라이브러리를 불러온 후, 요청을 진행해봅시다.
import requests
from bs4 import BeautifulSoup

# 두번째 인자 : header (key,value)
res = requests.get('https://hashcode.co.kr/', user_agent)

# %%
# 응답을 바탕으로 BeautifulSoup 객체를 생성해봅시다.
soup = BeautifulSoup(res.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko" xml:lang="ko" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta charset="utf-8"/>
# <title>QnA | 프로그래머스 커뮤니티</title>
# <link href="https://qna.programmers.co.kr/assets/programmers-favicon/favicon-40b78633b6556a68c3da8e2125c31512fbd01d09906ab76c8a8ff289e494cadb.png" rel="shortcut icon" type="image/png"/>
# <link href="https://qna.programmers.co.kr/assets/programmers-favicon/apple-icon-6eafc2c4c58a21aef692d6e44ce99d41f999c71789f277317532d0a9c6db8976.png" rel="apple-touch-icon" type="image/png"/>
# <meta content="프로그래머스 QnA는 프로그래밍 문제해결을 위한 QnA서비스입니다. 프로그래밍과 관련해서 개발자들끼리 궁금한건 물어보고 아는건 함께 나눠요. C, Java, Python, Ruby등의 코드를 웹에서 직접 실행해 볼 수 있는 기능도 제공합니다. - 프로그래머스 커뮤니티" name="description"/>
# <meta content="개발자, 프로그래머, 질문, 답변, 스택오버플로우, developer, programmer, q&amp;amp;amp;a, question, answer, stackoverflow, stack overflow" name="keywords"/>
# <meta content="QnA | 프로그래머스 커뮤니티" itemprop="title name" name="twitter:title" property="og:title"/>
# <meta content="프로그래머스 QnA는 프로그래밍 문제해결을 위한 QnA서비스입니다. 프로그래밍과 관련해서 개발자들끼리 궁금한건 물어보고 아는건 함께 나눠요. C, Java, Python, Ruby등의 코드를 웹에서 직접 실행해 볼 수 있는 기능도 제공합니다. - 프로그래머스 커뮤니티" itemprop="description" name="twitter:description" property="og:description"/>
# <meta content="https://qna.programmers.co.kr/assets/icons/ic_meta-3905ca60b60d4aaab3077219145ff3abaa2e27908a392d57302ed7338c123324.png" itemprop="image primaryImageOfPage" name="twitter:image" property="og:image"/>
# <meta content="https://qna.programmers.co.kr/" name="twitter:url" property="og:url"/>
# <meta content="website" property="og:type"/>
# <meta content="프로그래머스 커뮤니티" property="og:site_name"/>
# <meta content="ko_KR" property="og:locale"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="602865629851387" property="fb:app_id"/>
# <meta content="d10663d62c846bed2941445663b1dee131ff34ed" name="naver-site-verification"/>
# <meta content="#5C6BC0" name="theme-color"/>
# <link href="/assets/application-e1fac88b13fbe0eb35d6b11c1ee9bf79c6551adc742cfd831cd69e8ad497d35e.css" media="all" rel="stylesheet">
# <meta content="authenticity_token" name="csrf-param">
# <meta content="ubjlzfnbzcebQHjjso4v64AL4Xiy1HhbUYXmBv1LgAXCecN-R_ii6Ur6RY4DX8io886RlDABWZg3-1w0uNhvZA" name="csrf-token">
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#   j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#   'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-NT8HLJD');</script>
# <!-- End Google Tag Manager -->
# </meta></meta></link></head>
# <body class="root root-index" data-action="index" data-controller="root">
# <link href="https://d1nuzc1w51n1es.cloudfront.net/e8f1b057fbebc688c91b.css" rel="stylesheet"/><div id="main-app-gnb-header"><div class="wBcTdoNJJRdo0xD7ufvX main-app-gnb-component"><!-- --><!-- --><div class="hCYBlpNMGlZvS7LbULXz"><!--[--><div class="mcGzsRYdnPT9ZvqrXYvC kvgTVRn7krfmn_VldjxG"><div class="VBoPPgwf8YAoU2O184D0"><div class="QF988kxtUpsYP3isAW8o"><div class="ZCDMw94UqxBKyPQHNYSO"><a class="" href="https://programmers.co.kr"> 홈 </a><a class="" data-hackle-value="home_gnb_school_clicked" href="https://school.programmers.co.kr"> 스쿨 </a><a class="" data-hackle-value="home_gnb_career_clicked" href="https://career.programmers.co.kr"> 커리어 </a><a class="wobVcW4Oc8V0rSLB7mCv" data-hackle-value="home_gnb_community_clicked" href="https://community.programmers.co.kr"> 커뮤니티 </a></div><!-- --></div><div class="u55rqvzyeNwIq4iq4TTa"><a class="eCF67VVmX180QDxEarh1" href="https://community.programmers.co.kr"><svg fill="none" viewbox="0 0 304 26" xmlns="http://www.w3.org/2000/svg"><path d="M30.601 6.844h3.346V8.42h.049c.145-.213.331-.427.557-.64.243-.23.518-.434.825-.615.323-.18.67-.328 1.042-.443a4.005 4.005 0 011.188-.172c.873 0 1.665.156 2.376.468a4.973 4.973 0 011.819 1.279 5.496 5.496 0 011.188 1.943c.275.755.412 1.583.412 2.485 0 .836-.13 1.64-.388 2.41a6.325 6.325 0 01-1.067 2.018 5.24 5.24 0 01-1.673 1.427c-.662.344-1.414.516-2.255.516-.76 0-1.47-.115-2.133-.344a3.486 3.486 0 01-1.6-1.23h-.049v6.888h-3.637V6.844zm3.346 5.978c0 .902.25 1.632.752 2.19.517.557 1.236.836 2.158.836.921 0 1.632-.279 2.133-.836.517-.558.776-1.288.776-2.19 0-.902-.258-1.632-.776-2.19-.5-.557-1.212-.836-2.133-.836-.922 0-1.641.28-2.158.837-.501.557-.752 1.287-.752 2.19zM45 6.844h3.638v1.92h.048c.388-.739.849-1.288 1.382-1.649.534-.377 1.205-.566 2.013-.566.21 0 .42.008.63.025.21.016.404.049.582.098v3.37a4.39 4.39 0 00-.776-.172 3.897 3.897 0 00-.776-.074c-.695 0-1.244.099-1.648.296-.405.196-.72.475-.946.836-.21.344-.348.763-.412 1.255a12.506 12.506 0 00-.097 1.623V18.8H45V6.844zM53.479 12.822c0-.951.17-1.812.51-2.583.339-.77.8-1.427 1.381-1.968a6.196 6.196 0 012.085-1.279 7.432 7.432 0 012.57-.443c.906 0 1.754.148 2.546.443a5.895 5.895 0 012.085 1.28 5.735 5.735 0 011.407 1.967c.339.771.509 1.632.509 2.583 0 .951-.17 1.812-.51 2.583a5.995 5.995 0 01-1.406 1.993 6.087 6.087 0 01-2.085 1.254 7.231 7.231 0 01-2.546.443 7.432 7.432 0 01-2.57-.443 6.408 6.408 0 01-2.085-1.254 6.172 6.172 0 01-1.382-1.993c-.34-.77-.509-1.632-.509-2.583zm3.637 0c0 .902.25 1.632.752 2.19.517.557 1.236.836 2.157.836.922 0 1.633-.279 2.134-.836.517-.558.776-1.288.776-2.19 0-.902-.259-1.632-.776-2.19-.501-.557-1.212-.836-2.134-.836-.921 0-1.64.28-2.157.837-.502.557-.752 1.287-.752 2.19zM80.546 17.791c0 2.264-.565 3.977-1.697 5.142-1.115 1.18-2.82 1.771-5.116 1.771-1.05 0-2.085-.123-3.103-.369a6.852 6.852 0 01-2.813-1.378l2.013-3.05a7.699 7.699 0 001.77 1.132c.63.278 1.317.418 2.06.418 1.116 0 1.932-.279 2.45-.837.533-.54.8-1.238.8-2.09v-1.157h-.049c-.42.574-.946.984-1.576 1.23-.614.23-1.196.345-1.746.345-.873 0-1.665-.148-2.376-.443a5.66 5.66 0 01-1.842-1.28 5.96 5.96 0 01-1.164-1.967c-.275-.755-.412-1.583-.412-2.485 0-.787.12-1.558.363-2.312a6.692 6.692 0 011.067-1.993 5.356 5.356 0 011.697-1.378c.663-.36 1.415-.54 2.255-.54.517 0 .986.057 1.406.171.437.115.825.263 1.164.443.34.18.63.386.873.615.243.213.437.427.582.64h.049V6.844h3.345v10.947zm-9.165-5.043c0 .394.073.771.219 1.132.145.344.347.656.606.935.275.262.582.475.921.64.356.163.744.245 1.164.245.404 0 .784-.082 1.14-.246.355-.164.662-.377.92-.64.276-.278.486-.59.631-.934a3 3 0 00.219-1.132c0-.393-.073-.762-.219-1.107a2.644 2.644 0 00-.63-.934 2.899 2.899 0 00-.922-.665 2.688 2.688 0 00-1.139-.246c-.42 0-.808.082-1.164.246-.34.164-.646.386-.921.665-.259.262-.46.574-.606.934a2.815 2.815 0 00-.218 1.107zM82.92 6.844h3.637v1.92h.049c.388-.739.848-1.288 1.382-1.649.533-.377 1.204-.566 2.012-.566.21 0 .42.008.63.025.21.016.404.049.582.098v3.37a4.393 4.393 0 00-.776-.172 3.898 3.898 0 00-.776-.074c-.694 0-1.244.099-1.648.296-. ...
# <script defer="defer" src="https://d1nuzc1w51n1es.cloudfront.net/b8439eb1dc3650bad05d.js"></script>
# <div data-edu-component="community-header"></div>
# <script src="https://programmers.co.kr/env.js"></script>
# <div class="main">
# <div class="content">
# <div class="content-wrap">
# <div class="center">
# <div class="searchable-wrap">
# <div class="searchbar">
# <form accept-charset="UTF-8" action="/questions/search" method="get">
# <div class="input-group has-clear">
# <span class="input-group-addon icon-search"><span class="hc-icons-search">Search</span></span>
# <input class="form-control input" id="text" name="text" placeholder="질문을 검색하세요." required="required" type="text" value=""/>
# <span class="input-group-addon form-control-clear"><span class="hc-icons-l-x">Close</span> </span>
# </div>
# </form></div>
# <a class="btn-question" href="https://qna.programmers.co.kr/questions/new">
# <svg fill="none" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path clip-rule="evenodd" d="M20 5H4C2.9 5 2.01 5.9 2.01 7L2 17C2 18.1 2.9 19 4 19H20C21.1 19 22 18.1 22 17V7C22 5.9 21.1 5 20 5ZM11 8H13V10H11V8ZM11 11H13V13H11V11ZM8 8H10V10H8V8ZM8 11H10V13H8V11ZM7 13H5V11H7V13ZM7 10H5V8H7V10ZM16 17H8V15H16V17ZM16 13H14V11H16V13ZM16 10H14V8H16V10ZM19 13H17V11H19V13ZM19 10H17V8H19V10Z" fill="white" fill-rule="evenodd"></path>
# </svg>
# <span>작성하기</span>
# </a>
# </div>
# <ul class="nav nav-tabs" role="tablist">
# <li class="nav-item"><a class="nav-link active" href="https://qna.programmers.co.kr/">최신</a></li>
# <li class="nav-item"><a class="nav-link" href="https://qna.programmers.co.kr/?tab=hot">인기</a></li>
# <li class="nav-item"><a class="nav-link" href="https://qna.programmers.co.kr/?tab=answer">답변 필요</a></li>
# <li class="nav-item"><a class="nav-link" href="https://qna.programmers.co.kr/tags">태그 선택</a></li>
# </ul>
# <ul class="question-list">
# <li class="question-list-item" id="question-18398">
# <div class="question-view-count">
# <div class="question-number">5</div>
# <h6>조회</h6>
# </div>
# <div class="question-vote-count" data-id="18398">
# <div class="question-number">0</div>
# <h6>좋아요</h6>
# </div>
# <div class="question-answer-count" data-id="18398">
# <div class="question-number">0</div>
# <h6>답변</h6>
# </div>
# <div class="question">
# <div class="top">
# <h4><a href="/questions/18398/%ED%8F%AC%ED%8A%B8%EB%B2%88%ED%98%B8%EB%A5%BC-firewall-%EB%A1%9C-%EC%9D%B8%EB%B0%94%EC%9A%B4%EB%93%9C%EC%95%84%EC%9B%83%EB%B0%94%EC%9A%B4%EB%93%9C%EB%A5%BC-%EC%B0%A8%EB%8B%A8-%EC%84%A4%EC%A0%95%ED%95%98%EB%A9%B4-%EB%B3%B4%EC%95%88%EC%83%81-%EC%95%88%EC%A0%84%ED%95%98%EB%8B%A4%EA%B3%A0-%ED%95%A0-%EC%88%98-%EC%9E%88%EC%9D%84%EA%B9%8C%EC%9A%94">포트번호를 firewall 로 인바운드&amp;아웃바운드를 차단 설정하면 보안상 안전하다고 할 수 있을까요? </a></h4>
# </div>
# <ul class="question-tags">
# <li class="label label-tag">
# <a href="/questions/tagged/security" rel="tag">
# <span data-tag="security">security</span>
# </a> </li>
# <li class="label label-tag">
# <a href="/questions/tagged/windows" rel="tag">
# <span data-tag="windows">windows</span>
# </a> </li>
# <li class="label label-tag">
# <a href="/questions/tagged/firewall" rel="tag">
# <span data-tag="firewall">firewall</span>
# </a> </li>
# </ul>
# <ul class="question-info">
# <li class="name"><a href="https://community.programmers.co.kr/users/5978/activity" title="광자">광자</a></li>
# <li class="time"><time datetime="2023-08-29T11:12:54+09:00">8시간 전</time></li>
# </ul>
# </div>
# </li>
# <li class="question-list-item" id="question-18394">
# <div class="question-view-count">
# <div class="question-number">29</div>
# <h6>조회</h6>
# </div>
# <div class="question-vote-count" data-id="18394">
# <div class="question-number">0</div>
# <h6>좋아요</h6>
# </div>
# <div class="question-answer-count" data-id="18394">
# <div class="question-number">0</div>
# <h6>답변</h6>
# </div>
# <div class="question">
# <div class="top">
# <h4><a href="/questions/18394/%EC%9D%B4%EB%AF%B8%EC%A7%80%EB%A5%BC-%ED%81%AC%EB%A1%A4%EB%A7%81%ED%95%98%EC%97%AC-%EB%8B%A4%EC%9A%B4%EB%A1%9C%EB%93%9C-%ED%95%A0%EB%95%8C-%EC%83%9D%EA%B8%B0%EB%8A%94-%EC%98%A4%EB%A5%98">이미지를 크롤링하여 다운로드 할때 생기는 오류</a></h4>
# </div>
# <ul class="question-tags">
# <li class="label label-tag">
# <a href="/questions/tagged/python" rel="tag">
# <span data-tag="python">python</span>
# </a> </li>
# <li class="label label-tag">
# <a href="/questions/tagged/selenium" rel="tag">
# <span data-tag="selenium">selenium</span>
# </a> </li>
# <li class="label label-tag">
# <a href="/questions/tagged/beautifulsoup" rel="tag">
# <span data-tag="beautifulsoup">beautifulsoup</span>
# </a> </li>
# <li class="label label-tag">
# <a href="/questions/tagged/urllib" rel="tag">
# <span data-tag="urllib">urllib</span>
# </a> </li>
# </ul>
# <ul class="question-info">
# <li class="name"><a href="https://community.programmers.co.kr/users/621057/activity" title="ㅇ우히">ㅇ우히</a></li>
# <li class="time"><time datetime="2023-08-25T18:05:20+09:00">4일 전</time></li>
# </ul>
# </div>
# </li>
# <li class="question-list-item" id="question-18392">
# <div class="question-view-count">
# <div class="question-number">36</div>
# <h6>조회</h6>
# </div>
# <div class="question-vote-count" data-id="18392">
# <div class="question-number">0</div>
# <h6>좋아요</h6>
# </div>
# <div class="question-answer-count" data-id="18392">
# <div class="question-number">0</div>
# <h6>답변</h6>
# </div>
# <div class="question">
# <div class="top">
# <h4><a href="/questions/18392/ai%ED%95%99%EC%8A%B5%EC%9D%84-%EB%B0%A9%ED%95%B4%ED%95%98%EB%8A%94-%EC%82%AC%EC%9D%B4%ED%8A%B8-%EA%B0%9C%EB%B0%9C%EC%9D%B4-%EA%B0%80%EB%8A%A5%ED%95%9C%EA%B0%80%EC%9A%94">ai학습을 방해하는 사이트 개발이 가능한가요?</a></h4>
# </div>
# <ul class="question-tags">
# <li class="label label-tag">
# <a href="/questions/tagged/ai" rel="tag">
# <span data-tag="ai">ai</span>
# </a> </li>
# <li class="label label-tag">
# <a href="/questions/tagged/image-processing" rel="tag">
# <span data-tag="image-processing">image-processing</span>
# </a> </li>
# </ul>
# <ul class="question-info">
# <li class="name"><a href="https://community.programmers.co.kr/users/620276/activity" title="seth1010">seth1010</a></li>
# <li class="time"><time datetime="2023-08-23T16:58:55+09:00">6일 전</time></li>
# </ul>
# </div>
# </li>
# <li class="question-list-item" id="question-18390">
# <div class="question-view-count">
# <div class="question-number">40</div>
# <h6>조회</h6>
# </div>
# <div class="question-vote-count" data-id="18390">
# <div class="question-number">0</div>
# <h6>좋아요</h6>
# </div>
# <div class="question-answer-count" data-id="18390">
# <div class="question-number">0</div>
# <h6>답변</h6>
# </div>
# <div class="question">
# <div class="top">
# <h4><a href="/questions/18390/%EC%9C%A0%EB%8B%88%ED%8B%B0-%EB%A6%AC%EB%93%AC%EA%B2%8C%EC%9E%84-%EC%A0%9C%EC%9E%91-%EB%A9%94%ED%8A%B8%EB%A1%9C%EB%86%88-%EC%A0%9C%EC%9E%91-%EA%B4%80%EB%A0%A8-%EC%A7%88%EB%AC%B8%EC%9E%85%EB%8B%88%EB%8B%A4">유니티 리듬게임 제작 (메트로놈 제작) 관련 질문입니다.</a></h4>
# </div>
# <ul class="question-tags">
# <li class="label label-tag">
# <a href="/questions/tagged/unity" rel="tag">
# <span data-tag="unity">unity</span>
# </a> </li>
# <li class="label label-tag">
# <a href="/questions/tagged/c%23" rel="tag">
# <span data-tag="c#">c#</span>
# </a> </li>
# </ul>
# <ul class="question-info">
# <li class="name"><a href="https://community.programmers.co.kr/users/619370/activity" title="강선우">강선우</a></li>
# <li class="time"><time datetime="2023-08-20T21:24:32+09:00">9일 전</time></li>
# </ul>
# </div>
# </li>
# <li class="question-list-item" id="question-18388">
# <div class="question-view-count">
# <div class="question-number">100</div>
# <h6>조회</h6>
# </div>
# <div class="question-vote-count" data-id="18388">
# <div class="question-number">0</div>
# <h6>좋아요</h6>
# </div>
# <div class="question-answer-count" data-id="18388">
# <div class="question-number">2</div>
# <h6>답변</h6>
# </div>
# <div class="question">
# <div class="top">
# <h4><a href="/questions/18388/if%EB%AC%B8-%EA%B8%B0%EC%B4%88-%EC%A7%88%EB%AC%B8%EA%B0%80%EB%8A%A5%ED%95%A0%EA%B9%8C%EC%9A%94">if문 기초 질문가능할까요?</a></h4>
# </div>
# <ul class="question-tags">
# <li class="label label-tag">
# <a href="/questions/tagged/c" rel="tag">
# <span data-tag="c">c</span>
# </a> </li>
# </ul>
# <ul class="question-info">
# <li class="name"><a href="https://community.programmers.co.kr/users/619228/activity" title="배민서">배민서</a></li>
# <li class="time"><time datetime="2023-08-19T20:16:02+09:00">10일 전</time></li>
# </ul>
# </div>
# </li>
# <li class="question-list-item" id="question-18386">
# <div class="question-view-count">
# <div class="question-number">53</div>
# <h6>조회</h6>
# </div>
# <div class="question-vote-count" data-id="18386">
# <div class="question-number">0</div>
# <h6>좋아요</h6>
# </div>
# <div class="question-answer-count" data-id="18386">
# <div class="question-number">0</div>
# <h6>답변</h6>
# </div>
# <div class="question">
# <div class="top">
# <h4><a href="/questions/18386/%EC%9B%B9-%EC%8A%A4%ED%81%AC%EB%9E%98%ED%95%91-%EB%8F%85%ED%95%99-%EC%A4%91%EC%9D%B8-%EC%B4%88%EB%A0%99%EC%9D%B4-%EC%A7%88%EB%AC%B8%ED%95%A9%EB%8B%88%EB%8B%A4">웹 스크래핑 독학 중인,, 초렙이 질문합니다 '-',,</a></h4>
# </div>
# <ul class="question-tags">
# <li class="label label-tag">
# <a href="/questions/tagged/scraping" rel="tag">
# <span data-tag="scraping">scraping</span>
# </a> </li>
# <li class="label label-tag">
# <a href="/questions/tagged/python" rel="tag">
# <span data-tag="python">python</span>
# </a> </li>
# <li class="label label-tag">
# <a href="/questions/tagged/requests" rel="tag">
# <span data-tag="requests">requests</span>
# </a> </li>
# </ul>
# <ul class="question-info">
# <li class="name"><a href="https://community.programmers.co.kr/users/618252/activity" title="하리보">하리보</a></li>
# <li class="time"><time datetime="2023-08-16T15:31:51+09:00">13일 전</time></li>
# </ul>
# </div>
# </li>
# <li class="question-list-item" id="question-18384">
# <div class="question-view-count">
# <div class="question-number">49</div>
# <h6>조회</h6>
# </div>
# <div class="question-vote-count" data-id="18384">
# <div class="question-number">0</div>
# <h6>좋아요</h6>
# </div>
# <div class="question-answer-count" data-id="18384">
# <div class="question-number">0</div>
# <h6>답변</h6>
# </div>
# <div class="question">
# <div class="top">
# <h4><a href="/questions/18384/attributeerror-module-scipy-has-no-attribute-_lib-%EC%A7%88%EB%AC%B8%EB%93%9C%EB%A6%BD%EB%8B%88%EB%8B%A4">AttributeError: Module 'scipy' has no attribute '_lib' 질문드립니다.</a></h4>
# </div>
# <ul class="question-tags">
# <li class="label label-tag">
# <a href="/questions/tagged/python" rel="tag">
# <span data-tag="python">python</span>
# </a> </li>
# </ul>
# <ul class="question-info">
# <li class="name"><a href="https://community.programmers.co.kr/users/617793/activity" title="신동수">신동수</a></li>
# <li class="time"><time datetime="2023-08-14T16:37:50+09:00">15일 전</time></li>
# </ul>
# </div>
# </li>
# <li class="question-list-item" id="question-18383">
# <div class="question-view-count">
# <div class="question-number">65</div>
# <h6>조회</h6>
# </div>
# <div class="question-vote-count" data-id="18383">
# <div class="question-number">0</div>
# <h6>좋아요</h6>
# </div>
# <div class="question-answer-count" data-id="18383">
# <div class="question-number">0</div>
# <h6>답변</h6>
# </div>
# <div class="question">
# <div class="top">
# <h4><a href="/questions/18383/%ED%98%84%EC%97%85-spring-%EA%B0%9C%EB%B0%9C%EC%97%90-%EB%8C%80%ED%95%9C-%EA%B6%81%EA%B8%88%EC%A6%9D">현업 spring 개발에 대한 궁금증</a></h4>
# </div>
# <ul class="question-tags">
# <li class="label label-tag">
# <a href="/questions/tagged/spring" rel="tag">
# <span data-tag="spring">spring</span>
# </a> </li>
# </ul>
# <ul class="question-info">
# <li class="name"><a href="https://community.programmers.co.kr/users/541218/activity" title="bse3808@gmail.com">bse3808@gmail.com</a></li>
# <li class="time"><time datetime="2023-08-14T13:15:25+09:00">15일 전</time></li>
# </ul>
# </div>
# </li>
# <li class="question-list-item" id="question-18382">
# <div class="question-view-count">
# <div class="question-number">135</div>
# <h6>조회</h6>
# </div>
# <div class="question-vote-count" data-id="18382">
# <div class="question-number">0</div>
# <h6>좋아요</h6>
# </div>
# <div class="question-answer-count" data-id="18382">
# <div class="question-number">0</div>
# <h6>답변</h6>
# </div>
# <div class="question">
# <div class="top">
# <h4><a href="/questions/18382/floating-point-%EC%A0%80%EC%9E%A5-%EB%B0%A9%EC%8B%9D-%EC%A7%88%EB%AC%B8-clang">floating point 저장 방식 질문 Clang</a></h4>
# </div>
# <ul class="question-tags">
# <li class="label label-tag">
# <a href="/questions/tagged/floatig-point" rel="tag">
# <span data-tag="floatig-point">floatig-point</span>
# </a> </li>
# <li class="label label-tag">
# <a href="/questions/tagged/c" rel="tag">
# <span data-tag="c">c</span>
# </a> </li>
# </ul>
# <ul class="question-info">
# <li class="name"><a href="https://community.programmers.co.kr/users/617353/activity" title="khesiv">khesiv</a></li>
# <li class="time"><time datetime="2023-08-12T21:34:04+09:00">17일 전</time></li>
# </ul>
# </div>
# </li>
# <li class="question-list-item" id="question-18379">
# <div class="question-view-count">
# <div class="question-number">52</div>
# <h6>조회</h6>
# </div>
# <div class="question-vote-count" data-id="18379">
# <div class="question-number">0</div>
# <h6>좋아요</h6>
# </div>
# <div class="question-answer-count" data-id="18379">
# <div class="question-number">0</div>
# <h6>답변</h6>
# </div>
# <div class="question">
# <div class="top">
# <h4><a href="/questions/18379/%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%A8%B8%EC%8A%A4-%EC%BD%94%EB%93%9C%EC%97%90%EB%94%94%ED%84%B0-%EB%B6%88%ED%8E%B8%ED%95%A8-%EC%A7%88%EB%AC%B8%EB%93%9C%EB%A0%A4%EC%9A%94">프로그래머스 코드에디터 불편함 질문드려요..</a></h4>
# </div>
# <ul class="question-tags">
# <li class="label label-tag">
# <a href="/questions/tagged/editor" rel="tag">
# <span data-tag="editor">editor</span>
# </a> </li>
# </ul>
# <ul class="question-info">
# <li class="name"><a href="https://community.programmers.co.kr/users/599289/activity" title="이건우">이건우</a></li>
# <li class="time"><time datetime="2023-08-11T13:35:17+09:00">18일 전</time></li>
# </ul>
# </div>
# </li>
# <li class="question-list-item" id="question-18378">
# <div class="question-view-count">
# <div class="question-number">56</div>
# <h6>조회</h6>
# </div>
# <div class="question-vote-count" data-id="18378">
# <div class="question-number">0</div>
# <h6>좋아요</h6>
# </div>
# <div class="question-answer-count" data-id="18378">
# <div class="question-number">0</div>
# <h6>답변</h6>
# </div>
# <div class="question">
# <div class="top">
# <h4><a href="/questions/18378/%EA%B0%9C%EC%9D%B8-%EC%9B%B9%EC%82%AC%EC%9D%B4%ED%8A%B8-%EC%97%85%EB%A1%9C%EB%93%9C-%ED%95%98%EB%A0%A4%EB%A9%B4">개인 웹사이트 업로드 하려면</a></h4>
# </div>
# <ul class="question-tags">
# <li class="label label-tag">
# <a href="/questions/tagged/html" rel="tag">
# <span data-tag="html">html</span>
# </a> </li>
# <li class="label label-tag">
# <a href="/questions/tagged/css" rel="tag">
# <span data-tag="css">css</span>
# </a> </li>
# </ul>
# <ul class="question-info">
# <li class="name"><a href="https://community.programmers.co.kr/users/616694/activity" title="jamie">jamie</a></li>
# <li class="time"><time datetime="2023-08-10T17:17:48+09:00">19일 전</time></li>
# </ul>
# </div>
# </li>
# <li class="question-list-item" id="question-18377">
# <div class="question-view-count">
# <div class="question-number">171</div>
# <h6>조회</h6>
# </div>
# <div class="question-vote-count" data-id="18377">
# <div class="question-number">0</div>
# <h6>좋아요</h6>
# </div>
# <div class="question-answer-count accepted" data-id="18377">
# <div class="question-number">✓1</div>
# <h6>답변</h6>
# </div>
# <div class="question">
# <div class="top">
# <h4><a href="/questions/18377/mfc-%ED%8F%AC%EC%9D%B8%ED%84%B0-%EB%B0%B0%EC%97%B4">mfc 포인터 배열</a></h4>
# </div>
# <ul class="question-tags">
# <li class="label label-tag">
# <a href="/questions/tagged/mfc" rel="tag">
# <span data-tag="mfc">mfc</span>
# </a> </li>
# <li class="label label-tag">
# <a href="/questions/tagged/pointer" rel="tag">
# <span data-tag="pointer">pointer</span>
# </a> </li>
# <li class="label label-tag">
# <a href="/questions/tagged/array" rel="tag">
# <span data-tag="array">array</span>
# </a> </li>
# <li class="label label-tag">
# <a href="/questions/tagged/c++" rel="tag">
# <span data-tag="c++">c++</span>
# </a> </li>
# <li class="label label-tag">
# <a href="/questions/tagged/visual-studio-2010" rel="tag">
# <span data-tag="visual-studio-2010">visual-studio-2010</span>
# </a> </li>
# </ul>
# <ul class="question-info">
# <li class="name"><a href="https://community.programmers.co.kr/users/408758/activity" title="황수민">황수민</a></li>
# <li class="time"><time datetime="2023-08-09T16:01:20+09:00">20일 전</time></li>
# </ul>
# </div>
# </li>
# <li class="question-list-item" id="question-18376">
# <div class="question-view-count">
# <div class="question-number">53</div>
# <h6>조회</h6>
# </div>
# <div class="question-vote-count" data-id="18376">
# <div class="question-number">0</div>
# <h6>좋아요</h6>
# </div>
# <div class="question-answer-count" data-id="18376">
# <div class="question-number">0</div>
# <h6>답변</h6>
# </div>
# <div class="question">
# <div class="top">
# <h4><a href="/questions/18376/%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%A8%B8%EC%8A%A4-%EB%AC%B8%EC%A0%9C%EB%A5%BC-%EB%A7%88%ED%81%AC%EB%8B%A4%EC%9A%B4-%ED%98%95%EC%8B%9D-%EA%B7%B8%EB%8C%80%EB%A1%9C-%EB%B2%A8%EB%A1%9C%EA%B7%B8%EC%97%90-%EB%B3%B5%EC%82%AC%ED%95%A0-%EC%88%98-%EC%9E%88%EB%82%98%EC%9A%94">프로그래머스 문제를 마크다운 형식 그대로 벨로그에 복사할 수 있나요? </a></h4>
# </div>
# <ul class="question-info">
# <li class="name"><a href="https://community.programmers.co.kr/users/542984/activity" title="woolzam777@gmail.com">woolzam777@gmail.com</a></li>
# <li class="time"><time datetime="2023-08-09T14:56:49+09:00">20일 전</time></li>
# </ul>
# </div>
# </li>
# <li class="question-list-item" id="question-18375">
# <div class="question-view-count">
# <div class="question-number">84</div>
# <h6>조회</h6>
# </div>
# <div class="question-vote-count" data-id="18375">
# <div class="question-number">0</div>
# <h6>좋아요</h6>
# </div>
# <div class="question-answer-count" data-id="18375">
# <div class="question-number">0</div>
# <h6>답변</h6>
# </div>
# <div class="question">
# <div class="top">
# <h4><a href="/questions/18375/java%EB%A1%9C-web-server-%EB%A7%8C%EB%93%9C%EB%8A%94-%EA%B3%BC%EC%A0%9C%EC%A4%91%EC%9D%B8%EB%8D%B0%EC%9A%94">java로 web server 만드는 과제중인데요..</a></h4>
# </div>
# <ul class="question-tags">
# <li class="label label-tag">
# <a href="/questions/tagged/java" rel="tag">
# <span data-tag="java">java</span>
# </a> </li>
# <li class="label label-tag">
# <a href="/questions/tagged/http" rel="tag">
# <span data-tag="http">http</span>
# </a> </li>
# <li class="label label-tag">
# <a href="/questions/tagged/socket-programming" rel="tag">
# <span data-tag="socket-programming">socket-programming</span>
# </a> </li>
# </ul>
# <ul class="question-info">
# <li class="name"><a href="https://community.programmers.co.kr/users/180976/activity" title="성인규">성인규</a></li>
# <li class="time"><time datetime="2023-08-08T09:10:39+09:00">21일 전</time></li>
# </ul>
# </div>
# </li>
# <li class="question-list-item" id="question-18374">
# <div class="question-view-count">
# <div class="question-number">53</div>
# <h6>조회</h6>
# </div>
# <div class="question-vote-count" data-id="18374">
# <div class="question-number">0</div>
# <h6>좋아요</h6>
# </div>
# <div class="question-answer-count" data-id="18374">
# <div class="question-number">0</div>
# <h6>답변</h6>
# </div>
# <div class="question">
# <div class="top">
# <h4><a href="/questions/18374/%ED%85%8D%EC%8A%A4%ED%8A%B8-%ED%8C%8C%EC%9D%BC%EC%97%90%EC%84%9C-%ED%8F%89%EA%B7%A0-%EB%8B%A8%EC%96%B4-%EA%B8%B8%EC%9D%B4-%EA%B5%AC%ED%95%98%EA%B8%B0-%ED%8C%8C%EC%9D%B4%EC%8D%AC-%EA%B8%B0%EC%B4%88">텍스트 파일에서 평균 단어 길이 구하기 파이썬 기초</a></h4>
# </div>
# <ul class="question-tags">
# <li class="label label-tag">
# <a href="/questions/tagged/python" rel="tag">
# <span data-tag="python">python</span>
# </a> </li>
# </ul>
# <ul class="question-info">
# <li class="name"><a href="https://community.programmers.co.kr/users/deleted/activity">알 수 없는 사용자</a></li>
# <li class="time"><time datetime="2023-08-07T18:06:19+09:00">22일 전</time></li>
# </ul>
# </div>
# </li>
# <li class="question-list-item" id="question-18371">
# <div class="question-view-count">
# <div class="question-number">200</div>
# <h6>조회</h6>
# </div>
# <div class="question-vote-count" data-id="18371">
# <div class="question-number">0</div>
# <h6>좋아요</h6>
# </div>
# <div class="question-answer-count" data-id="18371">
# <div class="question-number">1</div>
# <h6>답변</h6>
# </div>
# <div class="question">
# <div class="top">
# <h4><a href="/questions/18371/%ED%8C%8C%EC%9D%B4%EC%8D%AC-invalid-literal-for-int">파이썬 invalid literal for int</a></h4>
# </div>
# <ul class="question-tags">
# <li class="label label-tag">
# <a href="/questions/tagged/python" rel="tag">
# <span data-tag="python">python</span>
# </a> </li>
# </ul>
# <ul class="question-info">
# <li class="name"><a href="https://community.programmers.co.kr/users/614262/activity" title="dicomo">dicomo</a></li>
# <li class="time"><time datetime="2023-08-03T18:55:50+09:00">26일 전</time></li>
# </ul>
# </div>
# </li>
# <li class="question-list-item" id="question-18370">
# <div class="question-view-count">
# <div class="question-number">250</div>
# <h6>조회</h6>
# </div>
# <div class="question-vote-count" data-id="18370">
# <div class="question-number">0</div>
# <h6>좋아요</h6>
# </div>
# <div class="question-answer-count" data-id="18370">
# <div class="question-number">1</div>
# <h6>답변</h6>
# </div>
# <div class="question">
# <div class="top">
# <h4><a href="/questions/18370/%EC%BD%94%EB%94%A9%ED%85%8C%EC%8A%A4%ED%8A%B8-%EC%9D%91%EC%8B%9C-%EA%B7%9C%EC%A0%95-%EC%A7%88%EB%AC%B8">코딩테스트 응시 규정 질문</a></h4>
# </div>
# <ul class="question-tags">
# <li class="label label-tag">
# <a href="/questions/tagged/coding-test" rel="tag">
# <span data-tag="coding-test">coding-test</span>
# </a> </li>
# <li class="label label-tag">
# <a href="/questions/tagged/numpy" rel="tag">
# <span data-tag="numpy">numpy</span>
# </a> </li>
# </ul>
# <ul class="question-info">
# <li class="name"><a href="https://community.programmers.co.kr/users/613463/activity" title="hyunseung223@gmail.com">hyunseung223@gmail.com</a></li>
# <li class="time"><time datetime="2023-08-02T13:59:36+09:00">27일 전</time></li>
# </ul>
# </div>
# </li>
# <li class="question-list-item" id="question-18369">
# <div class="question-view-count">
# <div class="question-number">261</div>
# <h6>조회</h6>
# </div>
# <div class="question-vote-count" data-id="18369">
# <div class="question-number">0</div>
# <h6>좋아요</h6>
# </div>
# <div class="question-answer-count accepted" data-id="18369">
# <div class="question-number">✓1</div>
# <h6>답변</h6>
# </div>
# <div class="question">
# <div class="top">
# <h4><a href="/questions/18369/%EC%A7%84%EB%A1%9C-%EA%B3%B5%EB%B6%80-%EA%B3%A0%EB%AF%BC">진로, 공부 고민</a></h4>
# </div>
# <ul class="question-info">
# <li class="name"><a href="https://community.programmers.co.kr/users/584828/activity" title="박진영">박진영</a></li>
# <li class="time"><time datetime="2023-08-01T10:05:00+09:00">28일 전</time></li>
# </ul>
# </div>
# </li>
# <li class="question-list-item" id="question-18368">
# <div class="question-view-count">
# <div class="question-number">66</div>
# <h6>조회</h6>
# </div>
# <div class="question-vote-count" data-id="18368">
# <div class="question-number">0</div>
# <h6>좋아요</h6>
# </div>
# <div class="question-answer-count" data-id="18368">
# <div class="question-number">0</div>
# <h6>답변</h6>
# </div>
# <div class="question">
# <div class="top">
# <h4><a href="/questions/18368/%EB%9F%B0%ED%83%80%EC%9E%84-%EC%97%90%EB%9F%AC-accessnullpointer-%ED%95%B4%EA%B2%B0%EB%B0%A9%EC%95%88-%EB%B6%80%ED%83%81%EB%93%9C%EB%A6%BD%EB%8B%88%EB%8B%A4">런타임 에러 (AccessNullPointer) 해결방안 부탁드립니다!</a></h4>
# </div>
# <ul class="question-tags">
# <li class="label label-tag">
# <a href="/questions/tagged/c++" rel="tag">
# <span data-tag="c++">c++</span>
# </a> </li>
# <li class="label label-tag">
# <a href="/questions/tagged/algorithm" rel="tag">
# <span data-tag="algorithm">algorithm</span>
# </a> </li>
# </ul>
# <ul class="question-info">
# <li class="name"><a href="https://community.programmers.co.kr/users/406330/activity" title="선태욱">선태욱</a></li>
# <li class="time"><time datetime="2023-07-28T15:46:31+09:00">약 1개월 전</time></li>
# </ul>
# </div>
# </li>
# <li class="question-list-item" id="question-18367">
# <div class="question-view-count">
# <div class="question-number">310</div>
# <h6>조회</h6>
# </div>
# <div class="question-vote-count" data-id="18367">
# <div class="question-number">0</div>
# <h6>좋아요</h6>
# </div>
# <div class="question-answer-count accepted" data-id="18367">
# <div class="question-number">✓1</div>
# <h6>답변</h6>
# </div>
# <div class="question">
# <div class="top">
# <h4><a href="/questions/18367/%ED%8C%8C%EC%9D%B4%EC%8D%AC-%ED%8E%98%EC%9D%B4%EC%A7%80%EB%B3%84%EB%A1%9C-%EB%B6%84%EB%A6%AC%ED%95%B4%EC%84%9C-%EA%B4%80%EB%A6%AC-%ED%95%A0%EB%95%8C-%EC%98%A4%EB%A5%98-%EB%B0%9C%EC%83%9D%EB%90%A9%EB%8B%88%EB%8B%A4-%EB%8F%84%EC%99%80%EC%A3%BC%EC%84%B8%EC%9A%94-%E3%85%9C">[파이썬] 페이지별로 분리해서 관리 할때 오류 발생됩니다. 도와주세요 ㅜ</a></h4>
# </div>
# <ul class="question-tags">
# <li class="label label-tag">
# <a href="/questions/tagged/python" rel="tag">
# <span data-tag="python">python</span>
# </a> </li>
# <li class="label label-tag">
# <a href="/questions/tagged/tkinter" rel="tag">
# <span data-tag="tkinter">tkinter</span>
# </a> </li>
# <li class="label label-tag">
# <a href="/questions/tagged/import" rel="tag">
# <span data-tag="import">import</span>
# </a> </li>
# </ul>
# <ul class="question-info">
# <li class="name"><a href="https://community.programmers.co.kr/users/612551/activity" title="추원일">추원일</a></li>
# <li class="time"><time datetime="2023-07-28T14:20:52+09:00">약 1개월 전</time></li>
# </ul>
# </div>
# </li>
# <li class="question-list-item" id="question-18366">
# <div class="question-view-count">
# <div class="question-number">199</div>
# <h6>조회</h6>
# </div>
# <div class="question-vote-count" data-id="18366">
# <div class="question-number">0</div>
# <h6>좋아요</h6>
# </div>
# <div class="question-answer-count" data-id="18366">
# <div class="question-number">1</div>
# <h6>답변</h6>
# </div>
# <div class="question">
# <div class="top">
# <h4><a href="/questions/18366/%EC%BD%94%EB%93%9C-%EC%98%A4%EB%A5%98-sklearnlinear_model%EC%97%90%EC%84%9C-decisiontreeclassifier-%EC%9D%B4%EB%A6%84%EC%9D%84-%EA%B0%80%EC%A0%B8%EC%98%AC-%EC%88%98-%EC%97%86%EC%8A%B5%EB%8B%88%EB%8B%A4">코드 오류: "'sklearn.linear_model'에서 'DecisionTreeClassifier' 이름을 가져올 수 없습니다."</a></h4>
# </div>
# <ul class="question-tags">
# <li class="label label-tag">
# <a href="/questions/tagged/database" rel="tag">
# <span data-tag="database">database</span>
# </a> </li>
# </ul>
# <ul class="question-info">
# <li class="name"><a href="https://community.programmers.co.kr/users/488611/activity" title="Mobiwann">Mobiwann</a></li>
# <li class="time"><time datetime="2023-07-27T23:55:12+09:00">약 1개월 전</time></li>
# </ul>
# </div>
# </li>
# <li class="question-list-item" id="question-18365">
# <div class="question-view-count">
# <div class="question-number">289</div>
# <h6>조회</h6>
# </div>
# <div class="question-vote-count" data-id="18365">
# <div class="question-number">0</div>
# <h6>좋아요</h6>
# </div>
# <div class="question-answer-count" data-id="18365">
# <div class="question-number">1</div>
# <h6>답변</h6>
# </div>
# <div class="question">
# <div class="top">
# <h4><a href="/questions/18365/%ED%96%89%EB%8B%98%EB%8D%9C%EB%84%A4%EC%9D%B4%EB%B2%84-%ED%94%8C%EB%A0%88%EC%9D%B4%EC%8A%A4%EB%A6%AC%EB%B7%B0-%ED%81%AC%EB%A1%A4%EB%A7%81-%EC%A2%80-%EB%8F%84%EC%99%80%EC%A3%BC%EC%84%B8%EC%9A%94">행님덜~~네이버 플레이스리뷰 크롤링 좀 도와주세요!!!</a></h4>
# </div>
# <ul class="question-tags">
# <li class="label label-tag">
# <a href="/questions/tagged/crawling" rel="tag">
# <span data-tag="crawling">crawling</span>
# </a> </li>
# <li class="label label-tag">
# <a href="/questions/tagged/naver" rel="tag">
# <span data-tag="naver">naver</span>
# </a> </li>
# </ul>
# <ul class="question-info">
# <li class="name"><a href="https://community.programmers.co.kr/users/612278/activity" title="이민규">이민규</a></li>
# <li class="time"><time datetime="2023-07-27T16:10:26+09:00">약 1개월 전</time></li>
# </ul>
# </div>
# </li>
# <li class="question-list-item" id="question-18362">
# <div class="question-view-count">
# <div class="question-number">84</div>
# <h6>조회</h6>
# </div>
# <div class="question-vote-count" data-id="18362">
# <div class="question-number">0</div>
# <h6>좋아요</h6>
# </div>
# <div class="question-answer-count" data-id="18362">
# <div class="question-number">0</div>
# <h6>답변</h6>
# </div>
# <div class="question">
# <div class="top">
# <h4><a href="/questions/18362/aws-s3-axios-%ED%8C%8C%EB%9D%BC%EB%AF%B8%ED%84%B0%EA%B0%80-%EB%A1%9C%EC%BB%AC%EC%97%90%EC%84%A0-%EC%A0%84%EB%8B%AC%EB%90%98%EB%8A%94%EB%8D%B0-%EB%B0%B0%ED%8F%AC%EC%84%9C%EB%B2%84%EC%97%90%EC%84%9C%EB%8A%94-%EC%A0%84%EB%8B%AC%EB%90%98%EC%A7%80-%EC%95%8A%EC%8A%B5%EB%8B%88%EB%8B%A4">(AWS S3) axios 파라미터가 로컬에선 전달되는데 배포서버에서는 전달되지 않습니다</a></h4>
# </div>
# <ul class="question-tags">
# <li class="label label-tag">
# <a href="/questions/tagged/react" rel="tag">
# <span data-tag="react">react</span>
# </a> </li>
# <li class="label label-tag">
# <a href="/questions/tagged/axios" rel="tag">
# <span data-tag="axios">axios</span>
# </a> </li>
# <li class="label label-tag">
# <a href="/questions/tagged/s3" rel="tag">
# <span data-tag="s3">s3</span>
# </a> </li>
# <li class="label label-tag">
# <a href="/questions/tagged/cloudfront" rel="tag">
# <span data-tag="cloudfront">cloudfront</span>
# </a> </li>
# </ul>
# <ul class="question-info">
# <li class="name"><a href="https://community.programmers.co.kr/users/132590/activity" title="이건영">이건영</a></li>
# <li class="time"><time datetime="2023-07-26T13:30:57+09:00">약 1개월 전</time></li>
# </ul>
# </div>
# </li>
# <li class="question-list-item" id="question-18361">
# <div class="question-view-count">
# <div class="question-number">69</div>
# <h6>조회</h6>
# </div>
# <div class="question-vote-count" data-id="18361">
# <div class="question-number">0</div>
# <h6>좋아요</h6>
# </div>
# <div class="question-answer-count" data-id="18361">
# <div class="question-number">0</div>
# <h6>답변</h6>
# </div>
# <div class="question">
# <div class="top">
# <h4><a href="/questions/18361/responseentityexceptionhandler%EC%97%90%EC%84%9C-%EC%BA%90%EC%B9%98%ED%95%98%EC%A7%80-%EB%AA%BB%ED%95%98%EB%8A%94-%EC%98%88%EC%99%B8">ResponseEntityExceptionHandler에서 캐치하지 못하는 예외</a></h4>
# </div>
# <ul class="question-tags">
# <li class="label label-tag">
# <a href="/questions/tagged/spring" rel="tag">
# <span data-tag="spring">spring</span>
# </a> </li>
# <li class="label label-tag">
# <a href="/questions/tagged/boot" rel="tag">
# <span data-tag="boot">boot</span>
# </a> </li>
# <li class="label label-tag">
# <a href="/questions/tagged/exception" rel="tag">
# <span data-tag="exception">exception</span>
# </a> </li>
# <li class="label label-tag">
# <a href="/questions/tagged/error" rel="tag">
# <span data-tag="error">error</span>
# </a> </li>
# </ul>
# <ul class="question-info">
# <li class="name"><a href="https://community.programmers.co.kr/users/580657/activity" title="ukdroidisgood@gmail.com">ukdroidisgood@gmail.com</a></li>
# <li class="time"><time datetime="2023-07-25T10:32:53+09:00">약 1개월 전</time></li>
# </ul>
# </div>
# </li>
# <li class="question-list-item" id="question-18360">
# <div class="question-view-count">
# <div class="question-number">376</div>
# <h6>조회</h6>
# </div>
# <div class="question-vote-count" data-id="18360">
# <div class="question-number">0</div>
# <h6>좋아요</h6>
# </div>
# <div class="question-answer-count" data-id="18360">
# <div class="question-number">1</div>
# <h6>답변</h6>
# </div>
# <div class="question">
# <div class="top">
# <h4><a href="/questions/18360/%ED%8C%8C%EC%9D%B4%EC%8D%AC-%EB%94%95%EC%85%94%EB%84%88%EB%A6%AC-%ED%95%A9-%EC%B6%9C%EB%A0%A5">파이썬 딕셔너리 합 출력</a></h4>
# </div>
# <ul class="question-tags">
# <li class="label label-tag">
# <a href="/questions/tagged/python" rel="tag">
# <span data-tag="python">python</span>
# </a> </li>
# </ul>
# <ul class="question-info">
# <li class="name"><a href="https://community.programmers.co.kr/users/610725/activity" title="ruithe">ruithe</a></li>
# <li class="time"><time datetime="2023-07-23T18:01:53+09:00">약 1개월 전</time></li>
# </ul>
# </div>
# </li>
# <li class="question-list-item" id="question-18359">
# <div class="question-view-count">
# <div class="question-number">89</div>
# <h6>조회</h6>
# </div>
# <div class="question-vote-count" data-id="18359">
# <div class="question-number">0</div>
# <h6>좋아요</h6>
# </div>
# <div class="question-answer-count" data-id="18359">
# <div class="question-number">0</div>
# <h6>답변</h6>
# </div>
# <div class="question">
# <div class="top">
# <h4><a href="/questions/18359/%EC%BD%94%EB%94%A9%ED%85%8C%EC%8A%A4%ED%8A%B8-%EC%BF%BC%EB%A6%AC">코딩테스트 쿼리</a></h4>
# </div>
# <ul class="question-tags">
# <li class="label label-tag">
# <a href="/questions/tagged/coding-test" rel="tag">
# <span data-tag="coding-test">coding-test</span>
# </a> </li>
# <li class="label label-tag">
# <a href="/questions/tagged/querying" rel="tag">
# <span data-tag="querying">querying</span>
# </a> </li>
# </ul>
# <ul class="question-info">
# <li class="name"><a href="https://community.programmers.co.kr/users/504744/activity" title="j_jumee">j_jumee</a></li>
# <li class="time"><time datetime="2023-07-21T22:03:17+09:00">약 1개월 전</time></li>
# </ul>
# </div>
# </li>
# <li class="question-list-item" id="question-18358">
# <div class="question-view-count">
# <div class="question-number">63</div>
# <h6>조회</h6>
# </div>
# <div class="question-vote-count" data-id="18358">
# <div class="question-number">0</div>
# <h6>좋아요</h6>
# </div>
# <div class="question-answer-count" data-id="18358">
# <div class="question-number">0</div>
# <h6>답변</h6>
# </div>
# <div class="question">
# <div class="top">
# <h4><a href="/questions/18358/eai-%EC%9D%B8%ED%84%B0%ED%8E%98%EC%9D%B4%EC%8A%A4-%EA%B5%AC%EC%B6%95-%EC%98%88%EC%A0%9C-%EB%82%98-%EA%B5%90%EC%9C%A1%EC%9D%84-%EB%B0%9B%EC%9D%84-%EC%88%98-%EC%9E%88%EB%8A%94-%EC%82%AC%EC%9D%B4%ED%8A%B8%EA%B0%80-%EC%9E%88%EC%9D%84%EA%B9%8C%EC%9A%94">eai 인터페이스 구축 예제 나 교육을 받을 수 있는 사이트가 있을까요?</a></h4>
# </div>
# <ul class="question-info">
# <li class="name"><a href="https://community.programmers.co.kr/users/604012/activity" title="구병희">구병희</a></li>
# <li class="time"><time datetime="2023-07-20T08:12:46+09:00">약 1개월 전</time></li>
# </ul>
# </div>
# </li>
# <li class="question-list-item" id="question-18357">
# <div class="question-view-count">
# <div class="question-number">89</div>
# <h6>조회</h6>
# </div>
# <div class="question-vote-count" data-id="18357">
# <div class="question-number">0</div>
# <h6>좋아요</h6>
# </div>
# <div class="question-answer-count" data-id="18357">
# <div class="question-number">0</div>
# <h6>답변</h6>
# </div>
# <div class="question">
# <div class="top">
# <h4><a href="/questions/18357/%EC%9B%B9%EC%82%AC%EC%9D%B4%ED%8A%B8-%EB%AA%A8%EB%B0%94%EC%9D%BC%EC%97%90%EC%84%9C-%EC%9D%B4%EB%AF%B8%EC%A7%80%EA%B0%80-%EC%95%88-%EB%B3%B4%EC%97%AC%EC%9A%94-%EB%89%B4%EB%B9%84">웹사이트 모바일에서 이미지가 안 보여요 (뉴비)</a></h4>
# </div>
# <ul class="question-tags">
# <li class="label label-tag">
# <a href="/questions/tagged/html" rel="tag">
# <span data-tag="html">html</span>
# </a> </li>
# </ul>
# <ul class="question-info">
# <li class="name"><a href="https://community.programmers.co.kr/users/609252/activity" title=" 유우"> 유우</a></li>
# <li class="time"><time datetime="2023-07-18T22:30:50+09:00">약 1개월 전</time></li>
# </ul>
# </div>
# </li>
# <li class="question-list-item" id="question-18356">
# <div class="question-view-count">
# <div class="question-number">110</div>
# <h6>조회</h6>
# </div>
# <div class="question-vote-count" data-id="18356">
# <div class="question-number">0</div>
# <h6>좋아요</h6>
# </div>
# <div class="question-answer-count" data-id="18356">
# <div class="question-number">0</div>
# <h6>답변</h6>
# </div>
# <div class="question">
# <div class="top">
# <h4><a href="/questions/18356/%ED%8C%8C%EC%9D%B4%EC%8D%AC-%EC%A7%84%EC%A7%9C-%EC%A7%84%EC%A7%9C-%EA%B8%B0%EC%B4%88">파이썬 진짜 진짜 기초...</a></h4>
# </div>
# <ul class="question-tags">
# <li class="label label-tag">
# <a href="/questions/tagged/python" rel="tag">
# <span data-tag="python">python</span>
# </a> </li>
# </ul>
# <ul class="question-info">
# <li class="name"><a href="https://community.programmers.co.kr/users/608880/activity" title="병아리 개발자">병아리 개발자</a></li>
# <li class="time"><time datetime="2023-07-18T15:55:19+09:00">약 1개월 전</time></li>
# </ul>
# </div>
# </li>
# <li class="question-list-item" id="question-18353">
# <div class="question-view-count">
# <div class="question-number">130</div>
# <h6>조회</h6>
# </div>
# <div class="question-vote-count" data-id="18353">
# <div class="question-number">0</div>
# <h6>좋아요</h6>
# </div>
# <div class="question-answer-count" data-id="18353">
# <div class="question-number">0</div>
# <h6>답변</h6>
# </div>
# <div class="question">
# <div class="top">
# <h4><a href="/questions/18353/%EC%95%84%EB%82%98%EC%BD%98%EB%8B%A4-%EC%A3%BC%ED%94%BC%ED%84%B0-%EB%85%B8%ED%8A%B8%EB%B6%81-%EC%9D%B4%EB%8F%99">아나콘다 주피터 노트북 이동</a></h4>
# </div>
# <ul class="question-tags">
# <li class="label label-tag">
# <a href="/questions/tagged/error" rel="tag">
# <span data-tag="error">error</span>
# </a> </li>
# <li class="label label-tag">
# <a href="/questions/tagged/python" rel="tag">
# <span data-tag="python">python</span>
# </a> </li>
# </ul>
# <ul class="question-info">
# <li class="name"><a href="https://community.programmers.co.kr/users/607767/activity" title="최세훈">최세훈</a></li>
# <li class="time"><time datetime="2023-07-14T08:58:29+09:00">약 2개월 전</time></li>
# </ul>
# </div>
# </li>
# <li class="question-list-item" id="question-18352">
# <div class="question-view-count">
# <div class="question-number">84</div>
# <h6>조회</h6>
# </div>
# <div class="question-vote-count" data-id="18352">
# <div class="question-number">0</div>
# <h6>좋아요</h6>
# </div>
# <div class="question-answer-count" data-id="18352">
# <div class="question-number">0</div>
# <h6>답변</h6>
# </div>
# <div class="question">
# <div class="top">
# <h4><a href="/questions/18352/for%EB%AC%B8%EC%9D%84-%EC%9D%B4%EC%9A%A9%ED%95%9C-roi">for문을 이용한 roi</a></h4>
# </div>
# <ul class="question-tags">
# <li class="label label-tag">
# <a href="/questions/tagged/c++" rel="tag">
# <span data-tag="c++">c++</span>
# </a> </li>
# <li class="label label-tag">
# <a href="/questions/tagged/opencv" rel="tag">
# <span data-tag="opencv">opencv</span>
# </a> </li>
# </ul>
# <ul class="question-info">
# <li class="name"><a href="https://community.programmers.co.kr/users/349099/activity" title="이신혁">이신혁</a></li>
# <li class="time"><time datetime="2023-07-11T16:00:03+09:00">약 2개월 전</time></li>
# </ul>
# </div>
# </li>
# <li class="question-list-item" id="question-18351">
# <div class="question-view-count">
# <div class="question-number">462</div>
# <h6>조회</h6>
# </div>
# <div class="question-vote-count" data-id="18351">
# <div class="question-number">0</div>
# <h6>좋아요</h6>
# </div>
# <div class="question-answer-count" data-id="18351">
# <div class="question-number">1</div>
# <h6>답변</h6>
# </div>
# <div class="question">
# <div class="top">
# <h4><a href="/questions/18351/%ED%8C%8C%EC%9D%B4%EC%8D%AC-%ED%8C%90%EB%8B%A4%EC%8A%A4%EC%97%90%EC%84%9C-%EC%97%91%EC%85%80-%ED%8C%8C%EC%9D%BC-%EB%B6%88%EB%9F%AC%EC%98%A8-%ED%9B%84-%EB%8B%A4%EC%8B%9C-%EC%A0%80%EC%9E%A5%ED%95%A0%EB%95%8C-%EB%85%84%EC%9B%94%EC%9D%BC%EC%9D%B4-%EC%A0%80%EC%9E%A5%EC%9D%B4-%EC%95%8A%EB%90%98%EB%8A%94-%EB%B6%80%EB%B6%84-%ED%95%B4%EA%B2%B0-%EB%B0%A9%EB%B2%95-%EC%95%8C%EB%A0%A4-%EC%A3%BC%EC%8B%9C%EB%A9%B4-%EA%B3%A0%EB%A7%99%EA%B2%A0%EC%8A%B5%EB%8B%88%EB%8B%A4">파이썬 판다스에서 엑셀 파일 불러온 후 다시 저장할때 년월일이 저장이 않되는 부분 해결 방법 알려 주시면 고맙겠습니다.</a></h4>
# </div>
# <ul class="question-tags">
# <li class="label label-tag">
# <a href="/questions/tagged/python" rel="tag">
# <span data-tag="python">python</span>
# </a> </li>
# <li class="label label-tag">
# <a href="/questions/tagged/pandas" rel="tag">
# <span data-tag="pandas">pandas</span>
# </a> </li>
# <li class="label label-tag">
# <a href="/questions/tagged/excel" rel="tag">
# <span data-tag="excel">excel</span>
# </a> </li>
# <li class="label label-tag">
# <a href="/questions/tagged/save" rel="tag">
# <span data-tag="save">save</span>
# </a> </li>
# </ul>
# <ul class="question-info">
# <li class="name"><a href="https://community.programmers.co.kr/users/606104/activity" title="meta.com.vvip@gmail.com">meta.com.vvip@gmail.com</a></li>
# <li class="time"><time datetime="2023-07-10T11:35:26+09:00">약 2개월 전</time></li>
# </ul>
# </div>
# </li>
# <li class="question-list-item" id="question-18349">
# <div class="question-view-count">
# <div class="question-number">97</div>
# <h6>조회</h6>
# </div>
# <div class="question-vote-count" data-id="18349">
# <div class="question-number">0</div>
# <h6>좋아요</h6>
# </div>
# <div class="question-answer-count" data-id="18349">
# <div class="question-number">0</div>
# <h6>답변</h6>
# </div>
# <div class="question">
# <div class="top">
# <h4><a href="/questions/18349/%EC%9E%85%EB%A0%A5%EB%90%9C-%EC%88%AB%EC%9E%90%EB%93%A4-%EC%A4%91-%EA%B0%80%EC%9E%A5-%ED%81%B0-%EC%86%8C%EC%9D%B8%EC%88%98%EB%A5%BC-%EC%A7%80%EB%8B%8C-%EC%88%AB%EC%9E%90%EB%A5%BC-%EC%B0%BE%EB%8A%94-%EB%AC%B8%EC%A0%9C">입력된 숫자들 중 가장 큰 소인수를 지닌 숫자를 찾는 문제 </a></h4>
# </div>
# <ul class="question-tags">
# <li class="label label-tag">
# <a href="/questions/tagged/c++" rel="tag">
# <span data-tag="c++">c++</span>
# </a> </li>
# </ul>
# <ul class="question-info">
# <li class="name"><a href="https://community.programmers.co.kr/users/523183/activity" title="이의열">이의열</a></li>
# <li class="time"><time datetime="2023-07-08T17:38:29+09:00">약 2개월 전</time></li>
# </ul>
# </div>
# </li>
# <li class="question-list-item" id="question-18348">
# <div class="question-view-count">
# <div class="question-number">547</div>
# <h6>조회</h6>
# </div>
# <div class="question-vote-count" data-id="18348">
# <div class="question-number">0</div>
# <h6>좋아요</h6>
# </div>
# <div class="question-answer-count" data-id="18348">
# <div class="question-number">1</div>
# <h6>답변</h6>
# </div>
# <div class="question">
# <div class="top">
# <h4><a href="/questions/18348/%EA%B9%83-%ED%94%8C%EB%A1%9C%EC%9A%B0-%EA%B4%80%EB%A0%A8%EC%A7%88%EB%AC%B8">깃 플로우 관련질문</a></h4>
# </div>
# <ul class="question-tags">
# <li class="label label-tag">
# <a href="/questions/tagged/git" rel="tag">
# <span data-tag="git">git</span>
# </a> </li>
# </ul>
# <ul class="question-info">
# <li class="name"><a href="https://community.programmers.co.kr/users/200101/activity" title="denmus">denmus</a></li>
# <li class="time"><time datetime="2023-07-06T21:43:43+09:00">약 2개월 전</time></li>
# </ul>
# </div>
# </li>
# <li class="question-list-item" id="question-18340">
# <div class="question-view-count">
# <div class="question-number">143</div>
# <h6>조회</h6>
# </div>
# <div class="question-vote-count" data-id="18340">
# <div class="question-number">0</div>
# <h6>좋아요</h6>
# </div>
# <div class="question-answer-count" data-id="18340">
# ...
# <div class="question-number">0</div>
# <h6>좋아요</h6>
# </div>
# <div class="question-answer-count" data-id="18318">
# <div class="question-number">1</div>
# <h6>답변</h6>
# </div>
# <div class="question">
# <div class="top">
# <h4><a href="/questions/18318/python-%EC%B2%98%EC%9D%8C%EC%9D%B4%EC%97%AC%EC%84%9C-pandas%EC%A2%80-%EC%A7%88%EB%AC%B8-%EB%93%9C%EB%A6%BD%EB%8B%88%EB%8B%A4">python 처음이여서.. pandas좀 질문 드립니다!</a></h4>
# </div>
# <ul class="question-tags">
# <li class="label label-tag">
# <a href="/questions/tagged/python" rel="tag">
# <span data-tag="python">python</span>
# </a> </li>
# <li class="label label-tag">
# <a href="/questions/tagged/pandas" rel="tag">
# <span data-tag="pandas">pandas</span>
# </a> </li>
# <li class="label label-tag">
# <a href="/questions/tagged/dataframe" rel="tag">
# <span data-tag="dataframe">dataframe</span>
# </a> </li>
# </ul>
# <ul class="question-info">
# <li class="name"><a href="https://community.programmers.co.kr/users/595358/activity" title="passionty10@gmail.com">passionty10@gmail.com</a></li>
# <li class="time"><time datetime="2023-06-07T18:56:32+09:00">3개월 전</time></li>
# </ul>
# </div>
# </li>
# <li class="question-list-item" id="question-18316">
# <div class="question-view-count">
# <div class="question-number">782</div>
# <h6>조회</h6>
# </div>
# <div class="question-vote-count" data-id="18316">
# <div class="question-number">0</div>
# <h6>좋아요</h6>
# </div>
# <div class="question-answer-count" data-id="18316">
# <div class="question-number">1</div>
# <h6>답변</h6>
# </div>
# <div class="question">
# <div class="top">
# <h4><a href="/questions/18316/%EC%9E%90%EB%B0%94-%EA%B3%B5%EC%9B%90-%EC%82%B0%EC%B1%85-%EB%AC%B8%EC%A0%9C-%EB%9F%B0%ED%83%80%EC%9E%84-%EC%97%90%EB%9F%AC-%EA%B3%84%EC%86%8D-%ED%95%B4%EA%B2%B0-%EB%AA%BB%ED%95%98%EA%B3%A0-%EC%9E%88%EB%8A%94%EB%8D%B0-%EC%9B%90%EC%9D%B8-%EC%95%8C-%EC%88%98-%EC%9E%88%EC%9D%84%EA%B9%8C%EC%9A%94">자바 - [공원 산책] 문제 런타임 에러 계속 해결 못하고 있는데 원인 알 수 있을까요..</a></h4>
# </div>
# <ul class="question-tags">
# <li class="label label-tag">
# <a href="/questions/tagged/coding-test" rel="tag">
# <span data-tag="coding-test">coding-test</span>
# </a> </li>
# </ul>
# <ul class="question-info">
# <li class="name"><a href="https://community.programmers.co.kr/users/559484/activity" title="조동현">조동현</a></li>
# <li class="time"><time datetime="2023-06-05T15:23:51+09:00">3개월 전</time></li>
# </ul>
# </div>
# </li>
# <li class="question-list-item" id="question-18315">
# <div class="question-view-count">
# <div class="question-number">146</div>
# <h6>조회</h6>
# </div>
# <div class="question-vote-count" data-id="18315">
# <div class="question-number">0</div>
# <h6>좋아요</h6>
# </div>
# <div class="question-answer-count" data-id="18315">
# <div class="question-number">0</div>
# <h6>답변</h6>
# </div>
# <div class="question">
# <div class="top">
# <h4><a href="/questions/18315/%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D%EC%9D%84-%EC%B2%98%EC%9D%8C-%EC%8B%9C%EC%9E%91%ED%95%98%EB%A0%A4-%ED%95%98%EB%8A%94%EB%8D%B0-%EC%96%B4%EB%A0%A4%EC%9B%80%EC%9D%B4-%EC%9E%88%EC%96%B4-%EC%A7%88%EB%AC%B8-%EB%93%9C%EB%A6%BD%EB%8B%88%EB%8B%A4%EB%8F%84%EC%99%80%EC%A3%BC%EC%84%B8%EC%9A%94">프로그래밍을 처음 시작하려 하는데 어려움이 있어 질문 드립니다..도와주세요..</a></h4>
# </div>
# <ul class="question-info">
# <li class="name"><a href="https://community.programmers.co.kr/users/594663/activity" title="송창민">송창민</a></li>
# <li class="time"><time datetime="2023-06-05T12:18:35+09:00">3개월 전</time></li>
# </ul>
# </div>
# </li>
# <li class="question-list-item" id="question-18314">
# <div class="question-view-count">
# <div class="question-number">208</div>
# <h6>조회</h6>
# </div>
# <div class="question-vote-count" data-id="18314">
# <div class="question-number">1</div>
# <h6>좋아요</h6>
# </div>
# <div class="question-answer-count" data-id="18314">
# <div class="question-number">1</div>
# <h6>답변</h6>
# </div>
# <div class="question">
# <div class="top">
# <h4><a href="/questions/18314/%ED%8C%8C%EC%9D%B4%EC%8D%AC-args-kwargs-%EA%B4%80%EB%A0%A8-%EC%A7%88%EB%AC%B8">파이썬 *args, **kwargs 관련 질문</a></h4>
# </div>
# <ul class="question-tags">
# <li class="label label-tag">
# <a href="/questions/tagged/python" rel="tag">
# <span data-tag="python">python</span>
# </a> </li>
# </ul>
# <ul class="question-info">
# <li class="name"><a href="https://community.programmers.co.kr/users/590737/activity" title="장민정">장민정</a></li>
# <li class="time"><time datetime="2023-06-04T11:46:32+09:00">3개월 전</time></li>
# </ul>
# </div>
# </li>
# </ul>
# <nav class="" role="navigation"><ul class="pagination"><li class="prev previous_page disabled page-item"><a class="page-link" href="#">이전</a></li> <li class="active page-item"><a class="page-link" href="/?User-Agent=Mozilla%2F5.0+%28Macintosh%3B+Intel+Mac+OS+X+10_15_4%29+AppleWebKit%2F537.36+%28KHTML%2C+like+Gecko%29+Chrome%2F83.0.4103.97+Safari%2F537.36&amp;page=1">1</a></li> <li class="page-item"><a class="page-link" href="/?User-Agent=Mozilla%2F5.0+%28Macintosh%3B+Intel+Mac+OS+X+10_15_4%29+AppleWebKit%2F537.36+%28KHTML%2C+like+Gecko%29+Chrome%2F83.0.4103.97+Safari%2F537.36&amp;page=2" rel="next">2</a></li> <li class="page-item"><a class="page-link" href="/?User-Agent=Mozilla%2F5.0+%28Macintosh%3B+Intel+Mac+OS+X+10_15_4%29+AppleWebKit%2F537.36+%28KHTML%2C+like+Gecko%29+Chrome%2F83.0.4103.97+Safari%2F537.36&amp;page=3">3</a></li> <li class="page-item"><a class="page-link" href="/?User-Agent=Mozilla%2F5.0+%28Macintosh%3B+Intel+Mac+OS+X+10_15_4%29+AppleWebKit%2F537.36+%28KHTML%2C+like+Gecko%29+Chrome%2F83.0.4103.97+Safari%2F537.36&amp;page=4">4</a></li> <li class="page-item"><a class="page-link" href="/?User-Agent=Mozilla%2F5.0+%28Macintosh%3B+Intel+Mac+OS+X+10_15_4%29+AppleWebKit%2F537.36+%28KHTML%2C+like+Gecko%29+Chrome%2F83.0.4103.97+Safari%2F537.36&amp;page=5">5</a></li> <li class="page-item disabled"><a class="page-link" href="#">…</a></li> <li class="page-item"><a class="page-link" href="/?User-Agent=Mozilla%2F5.0+%28Macintosh%3B+Intel+Mac+OS+X+10_15_4%29+AppleWebKit%2F537.36+%28KHTML%2C+like+Gecko%29+Chrome%2F83.0.4103.97+Safari%2F537.36&amp;page=246">246</a></li> <li class="next next_page page-item"><a class="page-link" href="/?User-Agent=Mozilla%2F5.0+%28Macintosh%3B+Intel+Mac+OS+X+10_15_4%29+AppleWebKit%2F537.36+%28KHTML%2C+like+Gecko%29+Chrome%2F83.0.4103.97+Safari%2F537.36&amp;page=2" rel="next">다음</a></li></ul></nav>
# </div>
# <div class="right">
# <div class="banner m-b-30">
# <script defer="defer" src="https://d1nuzc1w51n1es.cloudfront.net/669f80efa69a353c7f11.js"></script>
# <div id="community-app-banner-vertical"></div>
# </div>
# <div class="leaders">
# <div class="leaders-header">
# <div class="title">
# <a class="info" href="/hall_of_fame">명예의 전당</a>
# <span class="hc-icons-ranking-guide" data-placement="bottom" data-tabindex="1" data-toggle="popover-ranking" data-trigger="hover">javascript:;</span>
# </div>
# <ul class="nav nav-tabs" id="tab" role="tablist">
# <li class="nav-item">
# <a class="nav-link active" data-tab-history="true" data-tab-history-changer="push" data-tab-history-update-url="true" data-toggle="tab" href="#total" role="tab">종합</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" data-tab-history="true" data-tab-history-changer="push" data-tab-history-update-url="true" data-toggle="tab" href="#weekly" role="tab">최근 7일</a>
# </li>
# </ul>
# </div>
# <div class="tab-content">
# <div class="tab-pane fade" id="weekly" role="tabpanel">
# <div class="inspection-wrap">
# <img height="160" src="/assets/img-frame-35af8ed9d8e8a5700c26abda1b1666ed6e95d1135cacd89830a39cebc99cdef7.png" width="186"/>
# <p>해당 기능은 점검 중에 있어요.</p>
# </div>
# <ul class="leaders-content">
# </ul>
# </div>
# <div class="tab-pane fade in active" id="total" role="tabpanel">
# <ul class="leaders-content">
# <li>
# <h5 class="leader-rank">1</h5>
# <a href="https://community.programmers.co.kr/users/5760/activity" title="정영훈"><img alt="정영훈" class="leader-image" src="https://res.cloudinary.com/eightcruz/image/fetch/c_lfill,h_32,w_32/https://avatars.githubusercontent.com/u/12976157%3Fv%3D3"/></a>
# <div class="leader-info">
# <a href="https://community.programmers.co.kr/users/5760/activity">
# <h6 class="leader-name">정영훈</h6>
# <h6 class="leader-score">15,699</h6>
# </a> <h6 class="leader-tags">
# <a href="/questions/tagged/python">python</a>, <a href="/questions/tagged/java">java</a>, <a href="/questions/tagged/c">c</a>
# </h6>
# </div>
# </li>
# <li>
# <h5 class="leader-rank">2</h5>
# <a href="https://community.programmers.co.kr/users/81197/activity" title="엽토군"><img alt="엽토군" class="leader-image" src="https://res.cloudinary.com/eightcruz/image/fetch/c_lfill,h_32,w_32/https://avatars1.githubusercontent.com/u/6017662%3Fv%3D4"/></a>
# <div class="leader-info">
# <a href="https://community.programmers.co.kr/users/81197/activity">
# <h6 class="leader-name">엽토군</h6>
# <h6 class="leader-score">9,931</h6>
# </a> <h6 class="leader-tags">
# <a href="/questions/tagged/python">python</a>, <a href="/questions/tagged/javascript">javascript</a>, <a href="/questions/tagged/html">html</a>
# </h6>
# </div>
# </li>
# <li>
# <h5 class="leader-rank">3</h5>
# <a href="https://community.programmers.co.kr/users/4702/activity" title="nowp"><img alt="nowp" class="leader-image" src="https://res.cloudinary.com/eightcruz/image/upload/c_lfill,h_32,w_32/bbmweev1ywwdh2iljluc"/></a>
# <div class="leader-info">
# <a href="https://community.programmers.co.kr/users/4702/activity">
# <h6 class="leader-name">nowp</h6>
# <h6 class="leader-score">9,211</h6>
# </a> <h6 class="leader-tags">
# <a href="/questions/tagged/python">python</a>, <a href="/questions/tagged/pandas">pandas</a>, <a href="/questions/tagged/list">list</a>
# </h6>
# </div>
# </li>
# <li>
# <h5 class="leader-rank">4</h5>
# <a href="https://community.programmers.co.kr/users/25/activity" title="정토드"><img alt="정토드" class="leader-image" src="https://res.cloudinary.com/eightcruz/image/upload/c_lfill,h_32,w_32/jkgqzb6ml2g9zczfrnhj"/></a>
# <div class="leader-info">
# <a href="https://community.programmers.co.kr/users/25/activity">
# <h6 class="leader-name">정토드</h6>
# <h6 class="leader-score">5,576</h6>
# </a> <h6 class="leader-tags">
# <a href="/questions/tagged/python">python</a>, <a href="/questions/tagged/django">django</a>, <a href="/questions/tagged/android">android</a>
# </h6>
# </div>
# </li>
# <li>
# <h5 class="leader-rank">5</h5>
# <a href="https://community.programmers.co.kr/users/4584/activity" title="허대영(소프트웨어융합대학)"><img alt="허대영(소프트웨어융합대학)" class="leader-image" src="https://res.cloudinary.com/eightcruz/image/upload/c_lfill,h_32,w_32/vqhpcfp5cepgtbqgwcwv"/></a>
# <div class="leader-info">
# <a href="https://community.programmers.co.kr/users/4584/activity">
# <h6 class="leader-name">허대영(소프트웨어융합대학)</h6>
# <h6 class="leader-score">4,723</h6>
# </a> <h6 class="leader-tags">
# <a href="/questions/tagged/java">java</a>, <a href="/questions/tagged/android">android</a>, <a href="/questions/tagged/mysql">mysql</a>
# </h6>
# </div>
# </li>
# <li>
# <h5 class="leader-rank">6</h5>
# <a href="https://community.programmers.co.kr/users/217293/activity" title="cheolsu"><img alt="cheolsu" class="leader-image" src="https://res.cloudinary.com/eightcruz/image/upload/c_lfill,h_32,w_32/wbacpfydjhpra5xtc0iy"/></a>
# <div class="leader-info">
# <a href="https://community.programmers.co.kr/users/217293/activity">
# <h6 class="leader-name">cheolsu</h6>
# <h6 class="leader-score">4,405</h6>
# </a> <h6 class="leader-tags">
# <a href="/questions/tagged/c">c</a>, <a href="/questions/tagged/c++">c++</a>, <a href="/questions/tagged/python">python</a>
# </h6>
# </div>
# </li>
# <li>
# <h5 class="leader-rank">7</h5>
# <a href="https://community.programmers.co.kr/users/5279/activity" title="편집요청빌런"><img alt="편집요청빌런" class="leader-image" src="https://res.cloudinary.com/eightcruz/image/upload/c_lfill,h_32,w_32/gpnje6tbiwjvqsdbfd4t"/></a>
# <div class="leader-info">
# <a href="https://community.programmers.co.kr/users/5279/activity">
# <h6 class="leader-name">편집요청빌런</h6>
# <h6 class="leader-score">3,226</h6>
# </a> <h6 class="leader-tags">
# <a href="/questions/tagged/javascript">javascript</a>, <a href="/questions/tagged/python">python</a>, <a href="/questions/tagged/java">java</a>
# </h6>
# </div>
# </li>
# <li>
# <h5 class="leader-rank">8</h5>
# <div class="leader-info">
# <a href="https://community.programmers.co.kr/users/91022/activity">
# <h6 class="leader-name">알 수 없는 사용자</h6>
# <h6 class="leader-score">2,793</h6>
# </a> <h6 class="leader-tags">
# <a href="/questions/tagged/javascript">javascript</a>, <a href="/questions/tagged/python">python</a>, <a href="/questions/tagged/jquery">jquery</a>
# </h6>
# </div>
# </li>
# <li>
# <h5 class="leader-rank">9</h5>
# <a href="https://community.programmers.co.kr/users/4681/activity" title="김선우"><img alt="김선우" class="leader-image" src="https://res.cloudinary.com/eightcruz/image/upload/c_lfill,h_32,w_32/cyr8j1mboep1fa75vkot"/></a>
# <div class="leader-info">
# <a href="https://community.programmers.co.kr/users/4681/activity">
# <h6 class="leader-name">김선우</h6>
# <h6 class="leader-score">2,444</h6>
# </a> <h6 class="leader-tags">
# <a href="/questions/tagged/java">java</a>, <a href="/questions/tagged/android">android</a>, <a href="/questions/tagged/python">python</a>
# </h6>
# </div>
# </li>
# <li>
# <h5 class="leader-rank">10</h5>
# <a href="https://community.programmers.co.kr/users/5339/activity" title="유동욱"><img alt="유동욱" class="leader-image" src="https://res.cloudinary.com/eightcruz/image/upload/c_lfill,h_32,w_32/default_profile_img2_h16rrd"/></a>
# <div class="leader-info">
# <a href="https://community.programmers.co.kr/users/5339/activity">
# <h6 class="leader-name">유동욱</h6>
# <h6 class="leader-score">2,128</h6>
# </a> <h6 class="leader-tags">
# <a href="/questions/tagged/c++">c++</a>, <a href="/questions/tagged/python">python</a>, <a href="/questions/tagged/c">c</a>
# </h6>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="popover-body" id="popover-content-ranking" style="display:none;">
# <div class="popover-body">
# <h1 class="title">(⌐■_■)<br/>점수 산정 기준</h1>
# <ul>
# <li><span>+5점 :</span>내 질문에 좋아요가 달림.</li>
# <li><span>+5점 :</span>내 질문에 달린 답변을 채택함.</li>
# <li><span>+10점 :</span>내가 올린 답변에 좋아요가 달림.</li>
# <li><span>+15점 :</span>내가 올린 답변이 채택됨.</li>
# <li><span>+2점 :</span>내가 올린 편집 요청이 반영됨.</li>
# <li><span>-1점 :</span>내가 다른 사람의 질문/답변에 싫어요를 누름.</li>
# <li><span>+2점 :</span>내가 싫어요를 누른 질문이나 답변의 좋아요 점수가 0보다 작음.</li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div data-edu-component="footer" id="main-app-gnb-footer"></div>
# <div aria-hidden="true" aria-labelledby="exampleModalLabel" class="modal fade" id="modal-dialog" role="dialog" tabindex="-1"></div>
# <div aria-hidden="true" class="modal fade" id="modal-require-login" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <button aria-label="Close" class="close" data-dismiss="modal" type="button">
# <span aria-hidden="true">×</span>
# </button>
# <h3 class="modal-title">로그인이 필요합니다.</h3>
# </div>
# <div class="modal-body">
#         로그인하시겠습니까?
#       </div>
# <div class="modal-footer">
# <button class="btn btn-default" data-dismiss="modal" type="button">취소</button>
# <a class="btn btn-primary" href="/users/login">로그인하기</a>
# </div>
# </div>
# </div>
# </div>
# <script src="/assets/application-f14f2ba7f533c123ec468ab34bf3fadc3a1b1ca31f126af55c0609dd1d02bc10.js"></script>
# <script type="text/javascript">
#     window.SENTRY_RELEASE = "e6e99215286882e3edcf0abba65019cde2f37b2e"
#     Sentry.init({
#       environment: "production",
#       dsn: "https://781694c5923248588e10a8dcc2bdc07d@o1070092.ingest.sentry.io/6158165",
#       integrations: [new Sentry.Integrations.BrowserTracing()],
#       // Set tracesSampleRate to 1.0 to capture 100%
#       // of transactions for performance monitoring.
#       // We recommend adjusting this value in production
#       tracesSampleRate: 0.002,
#       release: window.SENTRY_RELEASE,
#     });
#   </script>
# <script src="//widget.cloudinary.com/global/all.js" type="text/javascript">
#   cloudinary.setCloudName('eightcruz');
# </script>
# <script src="//cdnjs.cloudflare.com/ajax/libs/highlight.js/9.1.0/highlight.min.js"></script>
# <noscript>
#   이 사이트의 기능을 모두 활용하기 위해서는 자바스크립트를 활성화 시킬 필요가 있습니다.
#   <a href="http://www.enable-javascript.com/ko/" target="_blank">
#     브라우저에서 자바스크립트를 활성화하는 방법</a>을 참고 하세요.
# </noscript>
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NT8HLJD" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# </body>
# </html>

# %%
# 제목 모으기
questions = soup.find_all('li','question-list-item')

for q in questions:
    print(q.find('div', 'question').find('div','top').h4.text)
# Out:
# 포트번호를 firewall 로 인바운드&아웃바운드를 차단 설정하면 보안상 안전하다고 할 수 있을까요?
# 이미지를 크롤링하여 다운로드 할때 생기는 오류
# ai학습을 방해하는 사이트 개발이 가능한가요?
# 유니티 리듬게임 제작 (메트로놈 제작) 관련 질문입니다.
# if문 기초 질문가능할까요?
# 웹 스크래핑 독학 중인,, 초렙이 질문합니다 '-',,
# AttributeError: Module 'scipy' has no attribute '_lib' 질문드립니다.
# 현업 spring 개발에 대한 궁금증
# floating point 저장 방식 질문 Clang
# 프로그래머스 코드에디터 불편함 질문드려요..
# 개인 웹사이트 업로드 하려면
# mfc 포인터 배열
# 프로그래머스 문제를 마크다운 형식 그대로 벨로그에 복사할 수 있나요?
# java로 web server 만드는 과제중인데요..
# 텍스트 파일에서 평균 단어 길이 구하기 파이썬 기초
# 파이썬 invalid literal for int
# 코딩테스트 응시 규정 질문
# 진로, 공부 고민
# 런타임 에러 (AccessNullPointer) 해결방안 부탁드립니다!
# [파이썬] 페이지별로 분리해서 관리 할때 오류 발생됩니다. 도와주세요 ㅜ
# 코드 오류: "'sklearn.linear_model'에서 'DecisionTreeClassifier' 이름을 가져올 수 없습니다."
# 행님덜~~네이버 플레이스리뷰 크롤링 좀 도와주세요!!!
# (AWS S3) axios 파라미터가 로컬에선 전달되는데 배포서버에서는 전달되지 않습니다
# ResponseEntityExceptionHandler에서 캐치하지 못하는 예외
# 파이썬 딕셔너리 합 출력
# 코딩테스트 쿼리
# eai 인터페이스 구축 예제 나 교육을 받을 수 있는 사이트가 있을까요?
# 웹사이트 모바일에서 이미지가 안 보여요 (뉴비)
# 파이썬 진짜 진짜 기초...
# 아나콘다 주피터 노트북 이동
# for문을 이용한 roi
# 파이썬 판다스에서 엑셀 파일 불러온 후 다시 저장할때 년월일이 저장이 않되는 부분 해결 방법 알려 주시면 고맙겠습니다.
# 입력된 숫자들 중 가장 큰 소인수를 지닌 숫자를 찾는 문제
# 깃 플로우 관련질문
# 자바 출력 결과 질문 드립니다
# .bat 배치파일 날짜 지정 부분 질문드립니다
# 파이썬 문제 풀이중 이해가 안가는 부분이 생겨서 질문드립니다
# 백준 문제(bfs) 질문입니다
# fread함수 질문입니다.
# 이 코딩을 파이썬으로 바꿔주세요
# 엑셀의 표를 읽어와서, 조건부 서식 - 색조를 파이썬으로 구현하고 싶은데 어떻게 해야되나요?
# t-test, 다중공선성에 대해 잘 아시는분 계실까요??
# org.eclipse.jst.j2ee.project.facet.j2ee facet constants 에러메시지 도저히 못잡겠네요.
# File I/O할 때 .readlines()[:5]의 의미와 sourcefile/targetfile 의미
# 스택 오버플로우가 왜 발생하는 지 모르겠어요...
# 초보 자바 경로 인식에 관하여 질문 드립니다.(같은 경로에 있는 사진 파일을 하나는 인식을 하고 하나는 인식을 못합니다)
# python 처음이여서.. pandas좀 질문 드립니다!
# 자바 - [공원 산책] 문제 런타임 에러 계속 해결 못하고 있는데 원인 알 수 있을까요..
# 프로그래밍을 처음 시작하려 하는데 어려움이 있어 질문 드립니다..도와주세요..
# 파이썬 *args, **kwargs 관련 질문

# %%
# 질문의 빈도를 체크하는 dict를 만든 후, 빈도를 체크해봅시다.

# %% [markdown]
# ### Bonus: 페이지네이션(Pagination)
#
# 페이지네이션은 많은 정보를 인덱스로 구분하는 기법입니다.
# 저희가 진행하고 있는 사이트는 Query String을 통해서 이를 구분하는데요,
# 이를 감안해서 다시 한번 진행해봅시다.
#
# `https://hashcode.co.kr/?page={i}`

# %%
# Pagination이 되어있는 질문 리스트의 제목을 모두 가져와봅시다.
# 과도한 요청을 방지하기 위해 1초마다 요청을 보내봅시다.

import time 

for i in range(1,6):
    res = requests.get(f'https://hashcode.co.kr/?page={i}')
    soup = BeautifulSoup(res.text,'html.parser')

    questions = soup.find_all('li','question-list-item')

    for q in questions:
        print(q.find('div', 'question').find('div','top').h4.text)
    time.sleep(0.5)
# Out:
# 포트번호를 firewall 로 인바운드&아웃바운드를 차단 설정하면 보안상 안전하다고 할 수 있을까요?
# 이미지를 크롤링하여 다운로드 할때 생기는 오류
# ai학습을 방해하는 사이트 개발이 가능한가요?
# 유니티 리듬게임 제작 (메트로놈 제작) 관련 질문입니다.
# if문 기초 질문가능할까요?
# 웹 스크래핑 독학 중인,, 초렙이 질문합니다 '-',,
# AttributeError: Module 'scipy' has no attribute '_lib' 질문드립니다.
# 현업 spring 개발에 대한 궁금증
# floating point 저장 방식 질문 Clang
# 프로그래머스 코드에디터 불편함 질문드려요..
# 개인 웹사이트 업로드 하려면
# mfc 포인터 배열
# 프로그래머스 문제를 마크다운 형식 그대로 벨로그에 복사할 수 있나요?
# java로 web server 만드는 과제중인데요..
# 텍스트 파일에서 평균 단어 길이 구하기 파이썬 기초
# 파이썬 invalid literal for int
# 코딩테스트 응시 규정 질문
# 진로, 공부 고민
# 런타임 에러 (AccessNullPointer) 해결방안 부탁드립니다!
# [파이썬] 페이지별로 분리해서 관리 할때 오류 발생됩니다. 도와주세요 ㅜ
# 코드 오류: "'sklearn.linear_model'에서 'DecisionTreeClassifier' 이름을 가져올 수 없습니다."
# 행님덜~~네이버 플레이스리뷰 크롤링 좀 도와주세요!!!
# (AWS S3) axios 파라미터가 로컬에선 전달되는데 배포서버에서는 전달되지 않습니다
# ResponseEntityExceptionHandler에서 캐치하지 못하는 예외
# 파이썬 딕셔너리 합 출력
# 코딩테스트 쿼리
# eai 인터페이스 구축 예제 나 교육을 받을 수 있는 사이트가 있을까요?
# 웹사이트 모바일에서 이미지가 안 보여요 (뉴비)
# 파이썬 진짜 진짜 기초...
# 아나콘다 주피터 노트북 이동
# for문을 이용한 roi
# 파이썬 판다스에서 엑셀 파일 불러온 후 다시 저장할때 년월일이 저장이 않되는 부분 해결 방법 알려 주시면 고맙겠습니다.
# 입력된 숫자들 중 가장 큰 소인수를 지닌 숫자를 찾는 문제
# 깃 플로우 관련질문
# 자바 출력 결과 질문 드립니다
# .bat 배치파일 날짜 지정 부분 질문드립니다
# 파이썬 문제 풀이중 이해가 안가는 부분이 생겨서 질문드립니다
# 백준 문제(bfs) 질문입니다
# fread함수 질문입니다.
# 이 코딩을 파이썬으로 바꿔주세요
# 엑셀의 표를 읽어와서, 조건부 서식 - 색조를 파이썬으로 구현하고 싶은데 어떻게 해야되나요?
# t-test, 다중공선성에 대해 잘 아시는분 계실까요??
# org.eclipse.jst.j2ee.project.facet.j2ee facet constants 에러메시지 도저히 못잡겠네요.
# File I/O할 때 .readlines()[:5]의 의미와 sourcefile/targetfile 의미
# 스택 오버플로우가 왜 발생하는 지 모르겠어요...
# 초보 자바 경로 인식에 관하여 질문 드립니다.(같은 경로에 있는 사진 파일을 하나는 인식을 하고 하나는 인식을 못합니다)
# python 처음이여서.. pandas좀 질문 드립니다!
# 자바 - [공원 산책] 문제 런타임 에러 계속 해결 못하고 있는데 원인 알 수 있을까요..
# 프로그래밍을 처음 시작하려 하는데 어려움이 있어 질문 드립니다..도와주세요..
# 파이썬 *args, **kwargs 관련 질문
# 파이썬 전역변수에 대해 이해가 안가서요 답변 주실 수 있을까요?
# 파이썬 코드 질문 (파일 입출력 문제, count = [0] * 10이 어떤의미인지 모르겠습니다.)
# pyinstaller 고수님들 계신가요?
# 파이썬 문제 3가지
# Next.js API에서 쿠키 접근하는 방법
# 진짜 간단한 코딩 질문입니다. (c언어)
# 코딩 급한 질문 있습니다
# 확장 칼만필터 파이썬 코드로 구현 중 ValueError 발생
# Node.js 질문 드립니다ㅠㅠ
# 문제 군데 군데
# 코딩테스트 공부법 질문합니다..!
# pybig 모듈 파이썬에서 import 되지 않는 에러(ModuleNotFoundError )가 발생합니다.
# 이 학습 예제 출력이 왜 안되는지 알려주실분...
# 구글코랩Google colab Mecab 객체생성 에러
# 지금 코딩테스트 코드 실행 및 제출 저만 안되나요,,?
# C언어 문자열 출력에서 쓰레기 값 발생
# 자바스크립트 일주일 공부했는데 문자열 출력 문제도 못풀면 접어야 합니까
# 코딩테스트 연습 - 컨트롤 제트 문제 질문
# mave에서 ojdbc6 추가하는데 오류나요
# c++질문
# 프로그래머스 푼 답안을 인텔리제이에서도 실행하고 싶어요
# Mac m1에서 utm으로 centOS7 설치
# 올리브영 웹사이트 크롤링
# system("cls")가 동작하지않습니다.
# pandas 구간별 평균 구하는 방법
# 코딩테스트 응시 안내 관련 문의사항
# scanf_s에서 입력에 자꾸 오류가 나타나는데, 어찌 해결해야 할까요?
# xgboost 하이퍼파라미터 질문
# 정수를 입력받아 짝수의 합과 홀수의 합을 구하는 프로그램
# 프로그래머스 vim 입력모드->일반모드 전환하는 방법
# 파이썬 프로젝트 중 오류
# 구조체 사용하여 다항식의 덧셈 구현하는 문제
# Fourier transform 된 사진파일의 HPF 코으
# 다시 매개변수화되어야 하는 매개변수화된 메서드 작성
# 파이썬 간단한 별그리기 질문
# Java 홀수 혹은 짝수의 합 구하는 프로그램 질문
# c언어 마름모 출력 프로그램
# 컴퓨터 시간을 기준으로 자동으로 그 시간이 되면 제가 설정한 문구를 타이핑 할 수 있게 만드는데 잘 작동하지 않습니다
# 4종류의 강아지를 분류하는 코드로 다람쥐와 청설모를 분류하는 코드를 만들었습니다. 이미지 파일만 다람쥐 파일로 바꿨는데 거의 마지막에 KeyError가 발생.
# 가변인자..... 평균값 아직 초보라 아예 모르겠습니다. 식 알려주시ㅣ면 식으로 공부 하겠습니다 한번만 좀 알려주세요 ㅠㅠㅠ
# 파이썬 가변인자 * 를 사용하는 get_average_score 함수 구현하기
# 판다스 데이터프레임 합치기 질문
# C언어 헤더파일에서 int& x를 어떻게 사용해야 하는지 모르겠습니다.
# 오브젝트가 오른쪽에 있는지 왼쪽에 있는지 판별
# Android Java 휴대폰에서 동영상 재생 중 전원을 꺼도 동영상 재생이 일시 중지되지 않습니다.
# 파이썬 반복분 출력
# 자바 기초 코딩 더 깔끔하게 고칠수있을까요?
# 페이징 코드좀 만들어주세요
# 파이썬 코드 질문
# matplotlib 으로 막대그래프와 선그래프 그리기
# 파이썬 연결 리스트 질문드립니다.
# 공백삭제 관련질문드립니다
# [Pandas] dataframe for문으로 여러개 만들기.
# ai와 겨루는 3*3 틱텍토 게임 구현 코드를 짜는 중에 오류가 생겼습니다.
# GUI 구성 시 엔진 부분과 GUI 부분을 분리하는 철학, 방식, 메소드에 관한 조언
# 자바 객체선언 오류 질문입니다!
# 파이썬 간단한 코드 질문
# '''로 주석으로 만들었는데 왜 주석을 지우지 않으면 유니코드오류가 왜 나는지 모르겠어여
# #define 상수 선언떄
# 우분투 vmware 가상머신 오류
# 파이썬 멀티스레딩 질문
# 파이썬 엑셀 파일 읽기
# 머쓱이 스탬프 할때 답보기요
# BFS를 사용해도 무관한지 궁금합니다!
# C# 백준 25206 문제 뭐가 문제인지 확인시켜줄 고수분
# python 제너레이터화
# 리액트 쿼리에서 useQuery를 어떻게 사용해야하나요
# html/javascript 로 node.js통해서 아두이노 통신관련
# Binary search tree
# Python 정규표현식을 사용한 패턴 추출
#  code: 'MODULE_NOT_FOUND' 좀 도와주세요
# 파이썬 데이터베이스 저장할때 다른방법없을까요?
# 코딩테스트 첫번째 폰켓몬 문제 왜 맞는건가요?
# 좋아요 한 문제만 따로 볼 수 있나요?
# 멀티프로세싱 프로그램 실행시 수십개의 프로그램이 실행됩니다.
# c언어 왜 소수점을 넣어야 결과가 나오나
# HTML 전혀 모르는데요
# QR코드만 이용해서 앱 개발을 하면 많이 힘들까요?
# (생초보) 파이썬 *매개변수의 개수
# 로지스틱 회귀
# 프로그래머스 코딩테스트 2단계 구명보트에서
# Java 개인 연습 중 배열에서 오류가 났는데 해결 방법을 모르겠습니다.
# 파이썬 csv 파일을 불러와 구분하는 방법에 대해 질문 드립니다
# 다음의 xarray를 어떻게 'time' series로 변형할 수 있는지 여쭈어봅니다.
# 'xlsx' file을 'nc' format으로 변환 후 저장하는 과정에서 계속 에러가 뜹니다..
# dayArray[dayOfWeek-1]  이건 어떻게 해석하나요?
# 파이썬 클래스 객체 생성에 관한 질문
# HashMap에서 equals 재정의할때 들어가는 Object가 뭔지좀 가르쳐주세요
# 파이썬 beautifulsoup 텍스트만 출력하기
# spy++, inspect가 특정 프로그램의 child windows를 불러오지 못하는 거 같습니다
# [python질문] i for i in range를 처음보는데 질문있습니다..
# 파이썬 웹크롤링 selenium 공부 중인데 계속 타입에러가 떠서 왜 오류가 이렇게 뜨는지 알  수 있을까요ㅠㅠ
# c언어 코딩테스트 level0 문제 어디가 문제 있나요?
# 한달 째 고민중인 cpp "char" 1byte send/receive 코드 질문 드립니다..ㅠㅠ
# 스킬 체크 테스트 Level.2 문제 2 Java 무한루프 문의드립니다.
# 자바스크립트 저장된 파일 제목으로 날짜 뽑는법 질문드립니다.
# 자바스크립트 세션 스토리지에 slider 발류 저장법
# Regex로 특정 단어부터 empty lines까지 찾는 법
# TimSort의 단점이 뭘까요?
# 파이썬 BeautifulSoup4 웹크롤링 관련 질문
# 자바스크립트 분수의 덧셈 질문입니다. 뭐가 문제인지 모르겠어요
# 맥에서 터미널을 킬때 이런 문구가 나옵니다
# 파이썬3 2차원배열 입력하기
# MFC 마우스 이벤트 처리 관련 질문입니다.
# 자바스크립트 질문있습니다.
# python의 os 모듈의 listdir함수에 대해 질문있습니다
# AttributeError at /admin/r/31/4/ 'NoneType' object has no attribute 'startswith'
# id.length==0 || id=="" 둘다 같은의미아닌가요?
# 자바 iterator 질문이요
# 파이썬 Django 질문이욧!!!
# javascript 의 재귀함수 문제
# c++ class 동적할당 배열 생성자
# 스프링 배치 writer 질문
# C++ STRCAT 구현부분 질문
# 파이썬 모듈 설치 하기
# [python3] Lv.1 신고 결과 받기 / 접근 방식 및 딕셔너리 값 관련 문제해결
# 동적배열을 이렇게 선언하면 안되는 이유가 있나요?
# qt 디자이너 사용해서 프린터와 pdf 저장하기 작성중입니다. 출력시 에러가 발생됩니다.메인 윈도우 창 전체를 프린터 및 pdf로 저장하고 싶습니다.
# Q&A 게시판 내 작성글 보기
# 서블릿 response관련 기초적인 질문할께요ㅠ
# [코틀린] private 질문
# live server 에서는 사진이 나오는데 Netlify로 사이트를 만들면 거기서는 사진이 안나와요
# 자바 코드 관련하여 질문드립니다
# 파이썬으로 서로 다른 두 데이터를 매칭하려 하는데 어떤 방법을 이용해야할지 좋을지 모르겠어요
# 영상을 프레임별 이미지로 변환
# scanf_s와 switch-case문 오류
# 라즈베리파이에서 사진 캡쳐 후 저장하는 코드를 짰는데 넘버링을 하고 싶습니다.
# hide(), show() 가 동기적으로 작동하지 않는데 문제점을 모르겠습니다.
# [VB.NET] POST 방식의 HTTPS 통신 시 에러 문제점
# 자료구조 다항식의 덧셈을 자바로 바꾸는 문제. delTerm 같은 함수들 활용법
# c언어 간단한 문제 질문 儆儆儆儆儆
# 아코디언 갤러리를 구현하려고 합니다.
# 파이썬 openpyxl 값 좌표 찾는 방법
# for문을 이용한 json 배열 배치하는 테이블 생성
# 판다스 read_excel() 소수점 질문
# c언어로 마방진 짜는 코드 질문이요
# 파이썬 장고(django) 프레임웍 환경에서 자동 로그인 구현하는 방법?
# 파이썬 타이머 버튼이 눌렸을 때 시간이 멈추도록
# 고수님들 파이썬 엑셀파일 만드는 코드좀 부탁드립니다
# sql 쿼리 : 특정 카테고리 직전 및 직후 구매한 카테고리
# overfitting 및 예측 data augmentation
# [판다스] 원천 데이터 프레임의 <>안의 문자만 뽑아 새로운 데이터 프레임 생성
# 파이선 체크박스 저장 & 불러오기 질문
# 파이썬 버블정렬구현
# dijkstra 최단경로
# 파이썬 이진탐색트리
# [파이썬] 판다스 중복 컬럼 찾기
# 과제요청 삭제 코딩 왕초보 입니다.... for문과 인덱싱을 활용한 딕셔너리 출력
# python -m pip install pyautogui 안되는데 이거 왜 그런건가요.
#  linearmodels install 질문
# 컴파일 후 에러 발생
# pygame 딜레이
# c언어 파일 출력시 儆儆이러한 문자가 뜨는 이유가 뭔가요?
# 리눅스 아니면 아이텀2에서 fxml파일을 만들려고 하는데
# html class 선언 코드 질문
# 터미널 alias 등록
# 파이썬 len(str([2,4])) 이 왜 6인가요?
# folium marker끼리 연결
# 자바 랜덤으로 1~6사이의 난수를 뽑는데 2,3,6만 뽑고싶습니다. 이럴땐 어떻게 코딩하나요?
# 파이선 데이터 저장 / 불러오기
# c언어 질문드립니다.
# Wamp 설치오류 도와주세요 ㅜ
# Location values cannot contain NaNs.
# (심사 중)이라는 메시지는 어떤 절차가 있다는 걸까요?
# PG결제 연동시 발생하는 보안이슈 문제질문드립니다.
# 입력한 위도와 경도와 csv 파일 내에 있는 위도와 경도 중 가장 가까운 위치 값 찾기
# 연결리스트 동적할당 알려주세요
# 100일 뒤 기념일 프로그램 코드좀 알려주세요 ㅠㅠ-ㅠ
# 영어단어 추출관련 코드 수정 문의
# CefSharp에서 WebRTC 사용 시 발생하는 문제
# colab list안에 있는 요소 옮기기
# bow_vect = vect.fit_transform 부분 오류가 나서 질문드립니다.
# 파이썬 BoW 벡터 진행 중 오류가 나서 질문 드립니다.
# ejs에서 실시간으로 db의 데이터를 가져오는 방법이 있을까요??
# 254개 - 248개 매칭 알고르짐에 관한 의견 구합니다.
# c언어 텍스트 파일
# if문 사용해서 8개의 패턴을 모두 프린트 하기
# 없는 자료에 대한 크롤링 처리
# VSC 포맷터 Prettier 사용중인데 이 빨간색을 어떻게 없애나요?
# 파이썬 openpyxl 관련 질문
# 이 코드에서 뭐가 생성자인가요?
# pyinstaller로 실행파일 만들 때 그 안에 임포트된 직접 만든 라이브러리 계속 업데이트 할 수 있을까요?
# 이 코딩 인수목록이 일치하지 않다는게 무슨말인가요?
# C언어 scanf로 수식을 입력받는 방법
# linux환경 c언어 프로세스 또는 쓰레드 종료 여부를 확인할 수 있는 방법이 궁금합니다
# 재귀구현(리커시브)을 사용해서 메소드 구현하기
# vscode에서 코드 색이 풀립니다.
# 거북이게임 목숨 추가
# 판다스 데이터프레임 열로 나열된 Group을 기준으로 각 항목의  Pair를 만들고 싶습니다
# 파이썬 클래스 상속 관련 질문입니다!
# 데이터프레임에서 전체 값이 0인 컬럼을 삭제하고싶습니다.
# 동적 게시판 생성시 테이블 설계 방법 문의
# JAVA GUI로 사거리 신호등 어떻게 구현하나요?
# 회원아이디가 텍스트에 나오게 하는것
# 파이썬 tkinter 중 dictionary
# 화면의 숫자 이미지를 읽어서 숫자 문자로 전환하는 코드가 있을까요?
# 파이썬 코드 질문입니다
# run 메소드 안에 loadPage 메소드 실행 시키는 방법이 궁금해요
# [ vue.js ] forEach문에서 store.dispatch를 통한 API 통신 시 에러 문제점
# 유닉스를 이용한 C 질문 argv
